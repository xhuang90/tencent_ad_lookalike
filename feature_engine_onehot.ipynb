# %%
from tqdm import tqdm
import os
import numpy as np
import time
import random
import pandas as pd
from scipy import sparse
from sklearn.metrics import roc_auc_score, log_loss
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from lightgbm import LGBMClassifier

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 读取数据集

# %%
data_org_dir = 'data/data_tencent/'
data_prep_dir = 'data/preprocess/'
# data_prep_dir = 'data/sample/'
sample_test = False

# %%
if sample_test:
    df_data = pd.read_csv(data_prep_dir + 'train_feat_merge_mini.csv')
else:
    df_data = pd.read_csv(data_prep_dir + 'train_feat_merge.csv')

train_idx_lst = list(df_data[df_data['n_parts'] != 1].index)
valid_idx_lst = list(df_data[df_data['n_parts'] == 1].index)

# %%
df_data.columns
# Out:
# Index(['n_parts', 'aid', 'uid', 'label', 'LBS', 'age', 'appIdAction',
#        'appIdInstall', 'carrier', 'consumptionAbility', 'ct', 'education',
#        'gender', 'house', 'interest1', 'interest2', 'interest3', 'interest4',
#        'interest5', 'kw1', 'kw2', 'kw3', 'marriageStatus', 'os', 'topic1',
#        'topic2', 'topic3', 'advertiserId', 'campaignId', 'creativeId',
#        'creativeSize', 'adCategoryId', 'productId', 'productType'],
#       dtype='object')

# %% [markdown]
# # 缺失率筛选

# %%
# 缺失情况统计
total = len(df_data)
for col_name in list(df_data.columns):
    df_missing = (df_data[df_data[col_name] == '-1'])
    
    print(col_name, ':', round(len(df_missing)/total, 2) * 100, '%')
# Out:
# n_parts : 0.0 %
# aid : 0.0 %
# uid : 0.0 %
# label : 0.0 %
# LBS : 0.0 %
# age : 0.0 %
# appIdAction : 98.0 %
# appIdInstall : 98.0 %
# carrier : 0.0 %
# consumptionAbility : 0.0 %
# ct : 0.0 %
# education : 0.0 %
# gender : 0.0 %
# house : 0.0 %
# interest1 : 9.0 %
# interest2 : 34.0 %
# interest3 : 97.0 %
# interest4 : 98.0 %
# interest5 : 25.0 %
# kw1 : 10.0 %
# kw2 : 3.0 %
# kw3 : 95.0 %
# marriageStatus : 0.0 %
# os : 0.0 %
# topic1 : 9.0 %
# topic2 : 4.0 %
# topic3 : 95.0 %
# advertiserId : 0.0 %
# campaignId : 0.0 %
# creativeId : 0.0 %
# creativeSize : 0.0 %
# adCategoryId : 0.0 %
# productId : 0.0 %
# productType : 0.0 %

# %% [markdown]
# ## 删除特征
#
# 1. 删除category特别大特别稀疏特征: 'appIdInstall', 'appIdAction', 'marriageStatus';
# 2. 删除缺失情况严重特征: 'interest3', 'interest4', 'kw3', 'topic3';

# %%
feat2drop = ['appIdInstall', 'appIdAction', 'marriageStatus', 'interest3', 'interest4', 'kw3', 'topic3']
df_data.drop(feat2drop, axis=1, inplace=True)

# %%
df_data.columns
# Out:
# Index(['n_parts', 'aid', 'uid', 'label', 'LBS', 'age', 'carrier',
#        'consumptionAbility', 'ct', 'education', 'gender', 'house', 'interest1',
#        'interest2', 'interest5', 'kw1', 'kw2', 'os', 'topic1', 'topic2',
#        'advertiserId', 'campaignId', 'creativeId', 'creativeSize',
#        'adCategoryId', 'productId', 'productType'],
#       dtype='object')

# %% [markdown]
# # 定长离散特征处理
# - 用户类: 'LBS', 'age', 'carrier', 'consumptionAbility', 'education', 'gender', 'house', 'os'
# - 广告类: 'aid', 'advertiserId', 'campaignId', 'creativeId', 'creativeSize', 'adCategoryId','productId', 'productType'

# %%
discrete_feat_lst = ['LBS', 'age', 'carrier', 'consumptionAbility', 'education', 'gender', 'house', 'os',
                     'aid', 'advertiserId', 'campaignId', 'creativeId', 'creativeSize', 'adCategoryId',
                     'productId', 'productType']
t0 = time.time()
for discrete_feat in tqdm(discrete_feat_lst):
    enc = LabelEncoder()
    try:
        df_data[discrete_feat] = enc.fit_transform(df_data[discrete_feat].apply(int))
    except:
        df_data[discrete_feat] = enc.fit_transform(df_data[discrete_feat])
# Out:
# 100%|██████████| 16/16 [01:02<00:00,  3.93s/it]

# %%
def one_hot_encoding(df_feat2enc):
    """

    :param df_feat2enc:
    :type df_feat2enc:
    :return:
    :rtype:
    """
    
    one_hot_enc.fit(df_feat2enc.values.reshape(-1, 1))
    feat_enc_arr = one_hot_enc.transform(df_feat2enc.values.reshape(-1, 1))#.toarray()

    return feat_enc_arr

# 数据量太大了, 一下子肝不完, 必须分开
discrete_feat_lst1 = ['LBS', 'age', 'carrier', 'consumptionAbility', 'education', 'gender']
discrete_feat_lst2 = ['aid', 'advertiserId', 'campaignId', 'creativeId', 'creativeSize']
discrete_feat_lst3 = ['adCategoryId', 'productId', 'productType', 'house', 'os']

discrete_feat = [discrete_feat_lst1, discrete_feat_lst2, discrete_feat_lst3]
# 初始化
one_hot_enc = OneHotEncoder()

x_train = pd.DataFrame()
x_valid = pd.DataFrame()
###### 数据量很大的时候用这个 ######
for feat_lst in discrete_feat:
    
    for feat in tqdm(feat_lst):
        # 合并训练
        df_feat2enc = df_data[feat]
        one_hot_enc.fit(df_feat2enc.values.reshape(-1, 1))
        # 训练集
        train2enc = df_data.loc[train_idx_lst][feat]
        train_enc_arr = one_hot_enc.transform(train2enc.values.reshape(-1, 1))
        x_train = sparse.hstack([x_train, train_enc_arr])
        # 验证集
        valid2enc = df_data.loc[valid_idx_lst][feat]
        valid_enc_arr = one_hot_enc.transform(valid2enc.values.reshape(-1, 1))
        x_valid = sparse.hstack([x_valid, valid_enc_arr])
    
train_f_dir = data_prep_dir + 'train_x_sparse_onehot.npz'
sparse.save_npz(train_f_dir, x_train)

valid_f_dir = data_prep_dir + 'valid_x_sparse_onehot.npz'
sparse.save_npz(valid_f_dir, x_valid)

print(train_f_dir, 'is saved! Array shape is', x_train.shape)
print(valid_f_dir, 'is saved! Array shape is', x_valid.shape)

###### 测试数据用这个 ######
# train_x = np.empty([len(train_idx_lst), 1], dtype=int)
# valid_x = np.empty([len(valid_idx_lst), 1], dtype=int) 
# for feat in tqdm(discrete_feat_lst):
    
#     # 训练集
#     df_feat2enc_train = df_data.loc[train_idx_lst][feat]
#     train_enc_arr = one_hot_encoding(df_feat2enc_train)
#     train_x = sparse.hstack([train_x, train_enc_arr])
#     # 验证集
#     df_feat2enc_valid = df_data.loc[valid_idx_lst][feat]
#     valid_enc_arr = one_hot_encoding(df_feat2enc_valid)
#     valid_x = sparse.hstack([valid_x, valid_enc_arr])
    
# train_f_dir = data_prep_dir + 'train_x_sparse_onehot.npz'
# sparse.save_npz(train_f_dir, train_enc_arr)

# valid_f_dir = data_prep_dir + 'valid_x_sparse_onehot.npz'
# sparse.save_npz(valid_f_dir, valid_enc_arr)

# print(train_f_dir, 'is saved! Array shape is', train_x.shape)
# print(valid_f_dir, 'is saved! Array shape is', valid_x.shape)
# Out:
# 100%|██████████| 6/6 [00:52<00:00,  8.73s/it]
# 100%|██████████| 5/5 [00:49<00:00,  9.98s/it]
# 100%|██████████| 5/5 [00:50<00:00, 10.15s/it]
# data/preprocess/train_x_sparse_onehot.npz is saved! Array shape is (7038840, 1526)
# data/preprocess/valid_x_sparse_onehot.npz is saved! Array shape is (1759974, 1526)

# %% [markdown]
# # 序列型特征处理
# - 用户类: 'ct', 'interest1', 'interest2', 'interest5', 'kw1', 'kw2', 'os'，'topic1', 'topic2',

# %%
sequence_feat_lst = ['ct', 'interest1', 'interest2', 'interest5', 'kw1', 'kw2', 'topic1', 'topic2']

# %% [markdown]
# ## 构建序列长度特征
# len_static_features = [x+'_len' for x in sequence_feat_lst]

# %%
# 初始化
x_train = pd.DataFrame()
x_valid = pd.DataFrame()

df_feat2len = df_data[sequence_feat_lst].applymap(lambda x: len(x.split(' ')))

# 构建训练集&验证集
df_train_enc = df_feat2len.loc[train_idx_lst].values
df_valid_enc = df_feat2len.loc[valid_idx_lst].values

x_train = sparse.hstack([x_train, df_train_enc])
x_valid = sparse.hstack([x_valid, df_valid_enc])

train_f_dir = data_prep_dir + 'train_x_sparse_seq_len.npz'
sparse.save_npz(train_f_dir, x_train)

valid_f_dir = data_prep_dir + 'valid_x_sparse_seq_len.npz'
sparse.save_npz(valid_f_dir, x_valid)

print(train_f_dir, 'is saved! Array shape is', x_train.shape)
print(valid_f_dir, 'is saved! Array shape is', x_valid.shape)
# Out:
# data/preprocess/train_x_sparse_seq_len.npz is saved! Array shape is (7038840, 8)
# data/preprocess/valid_x_sparse_seq_len.npz is saved! Array shape is (1759974, 8)

# %%
df_feat2len.shape
# Out:
# (8798814, 8)

# %% [markdown]
# ## 构建序列count特征

# %%
# 初始化
x_train = pd.DataFrame()
x_valid = pd.DataFrame()
cnt_enc = CountVectorizer()

for sequence_feat in tqdm(sequence_feat_lst[1:]):  # TODO: 'ct'未构建该类特征
    # 合并训练
    df_feat2cnt = df_data[sequence_feat]
    cnt_enc.fit(df_feat2cnt.values)
    # 训练集
    train2enc = df_data.loc[train_idx_lst][sequence_feat]
    train_enc_arr = cnt_enc.transform(train2enc.values)
    x_train = sparse.hstack([x_train, train_enc_arr])
    # 验证集
    valid2enc = df_data.loc[valid_idx_lst][sequence_feat]
    valid_enc_arr = cnt_enc.transform(valid2enc.values)
    x_valid = sparse.hstack([x_valid, valid_enc_arr])
    
train_f_dir = data_prep_dir + 'train_x_sparse_cntv.npz'
sparse.save_npz(train_f_dir, x_train)

valid_f_dir = data_prep_dir + 'valid_x_sparse_cntv.npz'
sparse.save_npz(valid_f_dir, x_valid)

print(train_f_dir, 'is saved! Array shape is', x_train.shape)
print(valid_f_dir, 'is saved! Array shape is', x_valid.shape)
# Out:
#   0%|          | 0/7 [03:33<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-b9f0491b3467> in <module>
#      14     # 验证集
#      15     valid2enc = df_data.loc[valid_idx_lst][sequence_feat]
# ---> 16     valid_enc_arr = cnt_enc.transform(valid2enc.values)
#      17     x_valid = sparse.hstack([x_valid, valid_enc_arr])
#      18
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py in transform(self, raw_documents)
#    1253
#    1254         # use the same matrix-building strategy as fit_transform
# -> 1255         _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#    1256         if self.binary:
#    1257             X.data.fill(1)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1117                     feature_idx = vocabulary[feature]
#    1118                     if feature_idx not in feature_counter:
# -> 1119                         feature_counter[feature_idx] = 1
#    1120                     else:
#    1121                         feature_counter[feature_idx] += 1
#
# KeyboardInterrupt:

# %% [markdown]
# # 用户id类特征处理（未处理）
# - 用户类: 'uid'
# 另外，因为也存在量大稀疏的问题，但是比赛的问题就是针对用户对广告的点击，因此uid对模型来说还是很有必要进行建模的，但是uid不使用category的方式建模，而是使用count和转化率建模：
# - uid_count : 对uid进行出现频次的建模。
# - uid_pos_count : 对uid进行正样本中的出现频次的建模。
# - uid_ad_features_pos_count : 对uid组合所有广告特征'ad_static_feature'进行正样本中的出现频次的建模。
# - 对uid进行如此多的建模方式是为了能对uid进行更加详细的表述，因为category的每一个特征就是一对一的，而count特征是多对一的，存在大量的信息损失，因此需要进行更多不同角度的建模，才能更好地表述uid。
# 特征方面还有一些长尾处理，未出现id的统一映射，长度和count特征的未出现次数的取临近值等trick。

# %% [markdown]
# # 特征选择
# ## 加载&合并特征

# %%
feat_fname_train = ['train_x_sparse_onehot.npz', 'train_x_sparse_seq_len.npz', 'train_x_sparse_cntv.npz']
feat_fname_valid = ['valid_x_sparse_onehot.npz', 'valid_x_sparse_seq_len.npz', 'valid_x_sparse_cntv.npz']
x_train = pd.DataFrame()
x_valid = pd.DataFrame()
for tr, vl in zip(feat_fname_train, feat_fname_valid):
    train_f = sparse.load_npz(data_prep_dir + tr).tocsr()
    valid_f = sparse.load_npz(data_prep_dir + vl).tocsr()
    
    x_train = sparse.hstack((x_train, train_f)).tocsc()
    x_valid = sparse.hstack((x_valid, valid_f)).tocsc()
    print(tr, train_f.shape)
    print(vl, valid_f.shape)
    
print('x_train:', x_train.shape)
print('x_valid:', x_valid.shape)

print('Loading & merging features completed!')
# Out:
# train_x_sparse_onehot.npz (7038840, 1526)
# valid_x_sparse_onehot.npz (1759974, 1526)
# train_x_sparse_seq_len.npz (7038840, 8)
# valid_x_sparse_seq_len.npz (1759974, 8)
# train_x_sparse_cntv.npz (7038840, 323142)
# valid_x_sparse_cntv.npz (1759974, 323142)
# x_train: (7038840, 324676)
# x_valid: (1759974, 324676)
# Loading & merging features completed!

# %%
# construct y vector
y_train = np.array(df_data[df_data['n_parts'] != 1]['label'])
y_valid = np.array(df_data[df_data['n_parts'] == 1]['label'])

print('y_train:', y_train.shape)
print('y_valid:', y_valid.shape)
# Out:
# y_train: (7038840,)
# y_valid: (1759974,)

# %% [markdown]
# ## LGB选择特征

# %%
import pandas as pd
from lightgbm import LGBMClassifier
import time
from sklearn.metrics import roc_auc_score
import warnings
warnings.filterwarnings('ignore')

# %%
clf = LGBMClassifier(boosting_type='gbdt',
                     num_leaves=31, max_depth=-1, 
                     learning_rate=0.1, n_estimators=10000, 
                     subsample_for_bin=200000, objective=None,
                     class_weight=None, min_split_gain=0.0, 
                     min_child_weight=0.001,
                     min_child_samples=20, subsample=1.0, subsample_freq=1,
                     colsample_bytree=1.0,
                     reg_alpha=0.0, reg_lambda=0.0, random_state=None,
                     n_jobs=-1, silent=False)

# %%
clf.fit(x_train, y_train, eval_set=[(x_train, y_train),(x_valid, y_valid)], 
        eval_names =['train','valid'],
        eval_metric='auc', early_stopping_rounds=100)
# Out:
# [LightGBM] [Info] Number of positive: 337465, number of negative: 6701375
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 1232.358202 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 240984
# [LightGBM] [Info] Number of data points in the train set: 7038840, number of used features: 120414
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.047943 -> initscore=-2.988606
# [LightGBM] [Info] Start training from score -2.988606
# [1]	train's auc: 0.633328	train's binary_logloss: 0.189736	valid's auc: 0.632434	valid's binary_logloss: 0.189924
# Training until validation scores don't improve for 100 rounds
# [2]	train's auc: 0.642899	train's binary_logloss: 0.188124	valid's auc: 0.641948	valid's binary_logloss: 0.18831
# [3]	train's auc: 0.651786	train's binary_logloss: 0.186984	valid's auc: 0.65073	valid's binary_logloss: 0.187172
# [4]	train's auc: 0.65381	train's binary_logloss: 0.186042	valid's auc: 0.652756	valid's binary_logloss: 0.186225
# [5]	train's auc: 0.658743	train's binary_logloss: 0.185289	valid's auc: 0.657766	valid's binary_logloss: 0.185468
# [6]	train's auc: 0.660897	train's binary_logloss: 0.184639	valid's auc: 0.659632	valid's binary_logloss: 0.184835
# [7]	train's auc: 0.666146	train's binary_logloss: 0.184003	valid's auc: 0.66509	valid's binary_logloss: 0.184208
# [8]	train's auc: 0.667427	train's binary_logloss: 0.183492	valid's auc: 0.666482	valid's binary_logloss: 0.183703
# [9]	train's auc: 0.669631	train's binary_logloss: 0.183067	valid's auc: 0.668636	valid's binary_logloss: 0.183277
# [10]	train's auc: 0.67162	train's binary_logloss: 0.182683	valid's auc: 0.670597	valid's binary_logloss: 0.182897
# [11]	train's auc: 0.674027	train's binary_logloss: 0.182316	valid's auc: 0.673061	valid's binary_logloss: 0.182535
# [12]	train's auc: 0.676365	train's binary_logloss: 0.182005	valid's auc: 0.675547	valid's binary_logloss: 0.182223
# [13]	train's auc: 0.678509	train's binary_logloss: 0.181693	valid's auc: 0.677696	valid's binary_logloss: 0.18191
# [14]	train's auc: 0.679428	train's binary_logloss: 0.181404	valid's auc: 0.678727	valid's binary_logloss: 0.181619
# [15]	train's auc: 0.680538	train's binary_logloss: 0.181181	valid's auc: 0.67986	valid's binary_logloss: 0.181397
# [16]	train's auc: 0.681873	train's binary_logloss: 0.180951	valid's auc: 0.681276	valid's binary_logloss: 0.181167
# [17]	train's auc: 0.68327	train's binary_logloss: 0.180735	valid's auc: 0.682654	valid's binary_logloss: 0.180956
# [18]	train's auc: 0.684914	train's binary_logloss: 0.180494	valid's auc: 0.684278	valid's binary_logloss: 0.180717
# [19]	train's auc: 0.685609	train's binary_logloss: 0.180324	valid's auc: 0.685044	valid's binary_logloss: 0.180551
# [20]	train's auc: 0.686847	train's binary_logloss: 0.180136	valid's auc: 0.686296	valid's binary_logloss: 0.180364
# [21]	train's auc: 0.687899	train's binary_logloss: 0.179972	valid's auc: 0.687323	valid's binary_logloss: 0.180202
# [22]	train's auc: 0.689326	train's binary_logloss: 0.179776	valid's auc: 0.688747	valid's binary_logloss: 0.180006
# [23]	train's auc: 0.689952	train's binary_logloss: 0.179638	valid's auc: 0.689308	valid's binary_logloss: 0.179872
# [24]	train's auc: 0.690756	train's binary_logloss: 0.179486	valid's auc: 0.690123	valid's binary_logloss: 0.179719
# [25]	train's auc: 0.691309	train's binary_logloss: 0.179347	valid's auc: 0.690689	valid's binary_logloss: 0.179577
# [26]	train's auc: 0.691982	train's binary_logloss: 0.179231	valid's auc: 0.691345	valid's binary_logloss: 0.179465
# [27]	train's auc: 0.692812	train's binary_logloss: 0.179099	valid's auc: 0.692268	valid's binary_logloss: 0.179328
# [28]	train's auc: 0.693291	train's binary_logloss: 0.178979	valid's auc: 0.69278	valid's binary_logloss: 0.179206
# [29]	train's auc: 0.693999	train's binary_logloss: 0.178862	valid's auc: 0.693514	valid's binary_logloss: 0.179088
# [30]	train's auc: 0.694672	train's binary_logloss: 0.178714	valid's auc: 0.694281	valid's binary_logloss: 0.178938
# [31]	train's auc: 0.695536	train's binary_logloss: 0.178593	valid's auc: 0.695151	valid's binary_logloss: 0.178818
# [32]	train's auc: 0.696149	train's binary_logloss: 0.178492	valid's auc: 0.695714	valid's binary_logloss: 0.17872
# [33]	train's auc: 0.69671	train's binary_logloss: 0.178383	valid's auc: 0.696334	valid's binary_logloss: 0.178611
# [34]	train's auc: 0.697246	train's binary_logloss: 0.178303	valid's auc: 0.696856	valid's binary_logloss: 0.178533
# [35]	train's auc: 0.697654	train's binary_logloss: 0.17819	valid's auc: 0.697242	valid's binary_logloss: 0.178426
# [36]	train's auc: 0.698081	train's binary_logloss: 0.178096	valid's auc: 0.697597	valid's binary_logloss: 0.178333
# [37]	train's auc: 0.698609	train's binary_logloss: 0.178002	valid's auc: 0.698134	valid's binary_logloss: 0.178238
# [38]	train's auc: 0.699631	train's binary_logloss: 0.177881	valid's auc: 0.699102	valid's binary_logloss: 0.178117
# [39]	train's auc: 0.70047	train's binary_logloss: 0.177776	valid's auc: 0.699963	valid's binary_logloss: 0.178011
# [40]	train's auc: 0.700873	train's binary_logloss: 0.177702	valid's auc: 0.700372	valid's binary_logloss: 0.177938
# [41]	train's auc: 0.701416	train's binary_logloss: 0.1776	valid's auc: 0.700879	valid's binary_logloss: 0.17784
# [42]	train's auc: 0.701809	train's binary_logloss: 0.177515	valid's auc: 0.701283	valid's binary_logloss: 0.177757
# [43]	train's auc: 0.702161	train's binary_logloss: 0.177452	valid's auc: 0.701637	valid's binary_logloss: 0.177696
# [44]	train's auc: 0.702632	train's binary_logloss: 0.177378	valid's auc: 0.702068	valid's binary_logloss: 0.177623
# [45]	train's auc: 0.702982	train's binary_logloss: 0.17729	valid's auc: 0.702399	valid's binary_logloss: 0.17754
# [46]	train's auc: 0.703577	train's binary_logloss: 0.177211	valid's auc: 0.703022	valid's binary_logloss: 0.177461
# [47]	train's auc: 0.703889	train's binary_logloss: 0.177141	valid's auc: 0.703359	valid's binary_logloss: 0.177391
# [48]	train's auc: 0.704262	train's binary_logloss: 0.17708	valid's auc: 0.70371	valid's binary_logloss: 0.177334
# [49]	train's auc: 0.70478	train's binary_logloss: 0.177004	valid's auc: 0.704202	valid's binary_logloss: 0.177258
# [50]	train's auc: 0.705186	train's binary_logloss: 0.176938	valid's auc: 0.704544	valid's binary_logloss: 0.177197
# [51]	train's auc: 0.705512	train's binary_logloss: 0.176877	valid's auc: 0.704893	valid's binary_logloss: 0.177135
# [52]	train's auc: 0.705824	train's binary_logloss: 0.176816	valid's auc: 0.705198	valid's binary_logloss: 0.177076
# [53]	train's auc: 0.706152	train's binary_logloss: 0.17675	valid's auc: 0.705486	valid's binary_logloss: 0.177013
# [54]	train's auc: 0.70661	train's binary_logloss: 0.176674	valid's auc: 0.705917	valid's binary_logloss: 0.176939
# [55]	train's auc: 0.706907	train's binary_logloss: 0.176609	valid's auc: 0.706203	valid's binary_logloss: 0.176877
# [56]	train's auc: 0.70726	train's binary_logloss: 0.176544	valid's auc: 0.706501	valid's binary_logloss: 0.176817
# [57]	train's auc: 0.707595	train's binary_logloss: 0.17649	valid's auc: 0.706816	valid's binary_logloss: 0.176766
# [58]	train's auc: 0.707905	train's binary_logloss: 0.176432	valid's auc: 0.707113	valid's binary_logloss: 0.176708
# [59]	train's auc: 0.708346	train's binary_logloss: 0.176375	valid's auc: 0.707543	valid's binary_logloss: 0.176652
# [60]	train's auc: 0.708538	train's binary_logloss: 0.176324	valid's auc: 0.707707	valid's binary_logloss: 0.176607
# [61]	train's auc: 0.70892	train's binary_logloss: 0.176271	valid's auc: 0.708076	valid's binary_logloss: 0.176557
# [62]	train's auc: 0.709192	train's binary_logloss: 0.176211	valid's auc: 0.708328	valid's binary_logloss: 0.1765
# [63]	train's auc: 0.709597	train's binary_logloss: 0.176145	valid's auc: 0.708707	valid's binary_logloss: 0.176435
# [64]	train's auc: 0.710097	train's binary_logloss: 0.176071	valid's auc: 0.709216	valid's binary_logloss: 0.17636
# [65]	train's auc: 0.710378	train's binary_logloss: 0.176019	valid's auc: 0.709488	valid's binary_logloss: 0.176309
# [66]	train's auc: 0.710689	train's binary_logloss: 0.175971	valid's auc: 0.709804	valid's binary_logloss: 0.17626
# [67]	train's auc: 0.71084	train's binary_logloss: 0.175929	valid's auc: 0.709956	valid's binary_logloss: 0.176219
# [68]	train's auc: 0.711066	train's binary_logloss: 0.175881	valid's auc: 0.710173	valid's binary_logloss: 0.176176
# [69]	train's auc: 0.71138	train's binary_logloss: 0.175826	valid's auc: 0.710459	valid's binary_logloss: 0.176124
# [70]	train's auc: 0.711542	train's binary_logloss: 0.175784	valid's auc: 0.710615	valid's binary_logloss: 0.176086
# [71]	train's auc: 0.711775	train's binary_logloss: 0.175744	valid's auc: 0.710852	valid's binary_logloss: 0.176045
# [72]	train's auc: 0.712111	train's binary_logloss: 0.175693	valid's auc: 0.71116	valid's binary_logloss: 0.176
# [73]	train's auc: 0.712392	train's binary_logloss: 0.175644	valid's auc: 0.711463	valid's binary_logloss: 0.175952
# [74]	train's auc: 0.712606	train's binary_logloss: 0.175607	valid's auc: 0.711684	valid's binary_logloss: 0.17592
# [75]	train's auc: 0.712826	train's binary_logloss: 0.175564	valid's auc: 0.711878	valid's binary_logloss: 0.17588
# [76]	train's auc: 0.713025	train's binary_logloss: 0.175526	valid's auc: 0.712083	valid's binary_logloss: 0.175842
# [77]	train's auc: 0.713253	train's binary_logloss: 0.175488	valid's auc: 0.712302	valid's binary_logloss: 0.175803
# [78]	train's auc: 0.713486	train's binary_logloss: 0.175435	valid's auc: 0.712477	valid's binary_logloss: 0.175755
# [79]	train's auc: 0.713741	train's binary_logloss: 0.1754	valid's auc: 0.712686	valid's binary_logloss: 0.175724
# [80]	train's auc: 0.713986	train's binary_logloss: 0.175357	valid's auc: 0.712926	valid's binary_logloss: 0.175685
# [81]	train's auc: 0.714309	train's binary_logloss: 0.175314	valid's auc: 0.71324	valid's binary_logloss: 0.175644
# [82]	train's auc: 0.714446	train's binary_logloss: 0.17528	valid's auc: 0.713356	valid's binary_logloss: 0.175613
# [83]	train's auc: 0.714623	train's binary_logloss: 0.175247	valid's auc: 0.713521	valid's binary_logloss: 0.175581
# [84]	train's auc: 0.714917	train's binary_logloss: 0.175195	valid's auc: 0.713785	valid's binary_logloss: 0.175529
# [85]	train's auc: 0.715067	train's binary_logloss: 0.175163	valid's auc: 0.713931	valid's binary_logloss: 0.175499
# [86]	train's auc: 0.715238	train's binary_logloss: 0.17513	valid's auc: 0.714109	valid's binary_logloss: 0.175465
# [87]	train's auc: 0.71554	train's binary_logloss: 0.175086	valid's auc: 0.714376	valid's binary_logloss: 0.175425
# [88]	train's auc: 0.71571	train's binary_logloss: 0.175052	valid's auc: 0.714522	valid's binary_logloss: 0.175394
# [89]	train's auc: 0.716129	train's binary_logloss: 0.175	valid's auc: 0.71495	valid's binary_logloss: 0.17534
# [90]	train's auc: 0.716255	train's binary_logloss: 0.174968	valid's auc: 0.715067	valid's binary_logloss: 0.175308
# [91]	train's auc: 0.716459	train's binary_logloss: 0.174922	valid's auc: 0.715277	valid's binary_logloss: 0.175263
# [92]	train's auc: 0.716559	train's binary_logloss: 0.174891	valid's auc: 0.715363	valid's binary_logloss: 0.175234
# [93]	train's auc: 0.716944	train's binary_logloss: 0.174842	valid's auc: 0.715737	valid's binary_logloss: 0.175188
# [94]	train's auc: 0.717177	train's binary_logloss: 0.174806	valid's auc: 0.71597	valid's binary_logloss: 0.175153
# [95]	train's auc: 0.717313	train's binary_logloss: 0.174763	valid's auc: 0.716073	valid's binary_logloss: 0.175115
# [96]	train's auc: 0.717512	train's binary_logloss: 0.174733	valid's auc: 0.716274	valid's binary_logloss: 0.175085
# [97]	train's auc: 0.717682	train's binary_logloss: 0.174702	valid's auc: 0.716422	valid's binary_logloss: 0.175058
# [98]	train's auc: 0.717845	train's binary_logloss: 0.174673	valid's auc: 0.71656	valid's binary_logloss: 0.175032
# [99]	train's auc: 0.718014	train's binary_logloss: 0.174648	valid's auc: 0.716681	valid's binary_logloss: 0.175013
# [100]	train's auc: 0.718197	train's binary_logloss: 0.174608	valid's auc: 0.716885	valid's binary_logloss: 0.174973
# [101]	train's auc: 0.718375	train's binary_logloss: 0.174579	valid's auc: 0.71704	valid's binary_logloss: 0.174949
# [102]	train's auc: 0.718527	train's binary_logloss: 0.174542	valid's auc: 0.717179	valid's binary_logloss: 0.174913
# [103]	train's auc: 0.718795	train's binary_logloss: 0.174505	valid's auc: 0.717457	valid's binary_logloss: 0.174874
# [104]	train's auc: 0.718947	train's binary_logloss: 0.174473	valid's auc: 0.717598	valid's binary_logloss: 0.174842
# [105]	train's auc: 0.719133	train's binary_logloss: 0.174434	valid's auc: 0.717769	valid's binary_logloss: 0.174808
# [106]	train's auc: 0.719439	train's binary_logloss: 0.174398	valid's auc: 0.718007	valid's binary_logloss: 0.174777
# [107]	train's auc: 0.719571	train's binary_logloss: 0.174363	valid's auc: 0.718139	valid's binary_logloss: 0.174745
# [108]	train's auc: 0.719693	train's binary_logloss: 0.174335	valid's auc: 0.718254	valid's binary_logloss: 0.174718
# [109]	train's auc: 0.719795	train's binary_logloss: 0.17431	valid's auc: 0.718338	valid's binary_logloss: 0.174695
# [110]	train's auc: 0.719908	train's binary_logloss: 0.174283	valid's auc: 0.718469	valid's binary_logloss: 0.174668
# [111]	train's auc: 0.720038	train's binary_logloss: 0.174257	valid's auc: 0.718567	valid's binary_logloss: 0.174647
# [112]	train's auc: 0.72042	train's binary_logloss: 0.174213	valid's auc: 0.718924	valid's binary_logloss: 0.174604
# [113]	train's auc: 0.720545	train's binary_logloss: 0.174187	valid's auc: 0.719015	valid's binary_logloss: 0.174582
# [114]	train's auc: 0.720733	train's binary_logloss: 0.174163	valid's auc: 0.719197	valid's binary_logloss: 0.17456
# [115]	train's auc: 0.720818	train's binary_logloss: 0.174139	valid's auc: 0.719275	valid's binary_logloss: 0.174539
# [116]	train's auc: 0.720921	train's binary_logloss: 0.174112	valid's auc: 0.719386	valid's binary_logloss: 0.174514
# [117]	train's auc: 0.721042	train's binary_logloss: 0.174082	valid's auc: 0.7195	valid's binary_logloss: 0.174487
# [118]	train's auc: 0.721174	train's binary_logloss: 0.174057	valid's auc: 0.71962	valid's binary_logloss: 0.174464
# [119]	train's auc: 0.721271	train's binary_logloss: 0.174035	valid's auc: 0.719725	valid's binary_logloss: 0.174441
# [120]	train's auc: 0.721524	train's binary_logloss: 0.174001	valid's auc: 0.719942	valid's binary_logloss: 0.174409
# [121]	train's auc: 0.721809	train's binary_logloss: 0.173968	valid's auc: 0.720199	valid's binary_logloss: 0.174379
# [122]	train's auc: 0.721948	train's binary_logloss: 0.173944	valid's auc: 0.720336	valid's binary_logloss: 0.174358
# [123]	train's auc: 0.722072	train's binary_logloss: 0.173921	valid's auc: 0.720419	valid's binary_logloss: 0.17434
# [124]	train's auc: 0.722194	train's binary_logloss: 0.173901	valid's auc: 0.720526	valid's binary_logloss: 0.174323
# [125]	train's auc: 0.722326	train's binary_logloss: 0.173872	valid's auc: 0.720639	valid's binary_logloss: 0.174298
# [126]	train's auc: 0.722458	train's binary_logloss: 0.17385	valid's auc: 0.720775	valid's binary_logloss: 0.174279
# [127]	train's auc: 0.722556	train's binary_logloss: 0.173831	valid's auc: 0.720836	valid's binary_logloss: 0.174264
# [128]	train's auc: 0.722631	train's binary_logloss: 0.17381	valid's auc: 0.720911	valid's binary_logloss: 0.174248
# [129]	train's auc: 0.722843	train's binary_logloss: 0.17378	valid's auc: 0.721122	valid's binary_logloss: 0.174218
# [130]	train's auc: 0.722921	train's binary_logloss: 0.173757	valid's auc: 0.72119	valid's binary_logloss: 0.174198
# [131]	train's auc: 0.723054	train's binary_logloss: 0.173731	valid's auc: 0.721338	valid's binary_logloss: 0.174173
# [132]	train's auc: 0.723162	train's binary_logloss: 0.173706	valid's auc: 0.721448	valid's binary_logloss: 0.174151
# [133]	train's auc: 0.723303	train's binary_logloss: 0.173681	valid's auc: 0.721554	valid's binary_logloss: 0.174129
# [134]	train's auc: 0.723599	train's binary_logloss: 0.173642	valid's auc: 0.721809	valid's binary_logloss: 0.174094
# [135]	train's auc: 0.723893	train's binary_logloss: 0.173606	valid's auc: 0.722103	valid's binary_logloss: 0.17406
# [136]	train's auc: 0.723979	train's binary_logloss: 0.173586	valid's auc: 0.722152	valid's binary_logloss: 0.174045
# [137]	train's auc: 0.724107	train's binary_logloss: 0.173567	valid's auc: 0.722243	valid's binary_logloss: 0.17403
# [138]	train's auc: 0.724205	train's binary_logloss: 0.173546	valid's auc: 0.722329	valid's binary_logloss: 0.17401
# [139]	train's auc: 0.724297	train's binary_logloss: 0.173527	valid's auc: 0.72241	valid's binary_logloss: 0.173992
# [140]	train's auc: 0.724414	train's binary_logloss: 0.173507	valid's auc: 0.722513	valid's binary_logloss: 0.173975
# [141]	train's auc: 0.72449	train's binary_logloss: 0.173488	valid's auc: 0.722587	valid's binary_logloss: 0.173957
# [142]	train's auc: 0.724685	train's binary_logloss: 0.173466	valid's auc: 0.722752	valid's binary_logloss: 0.173938
# [143]	train's auc: 0.724803	train's binary_logloss: 0.173444	valid's auc: 0.722849	valid's binary_logloss: 0.17392
# [144]	train's auc: 0.724926	train's binary_logloss: 0.173426	valid's auc: 0.722954	valid's binary_logloss: 0.173903
# [145]	train's auc: 0.72506	train's binary_logloss: 0.173403	valid's auc: 0.723069	valid's binary_logloss: 0.173883
# [146]	train's auc: 0.725153	train's binary_logloss: 0.173383	valid's auc: 0.723134	valid's binary_logloss: 0.173866
# [147]	train's auc: 0.725216	train's binary_logloss: 0.173365	valid's auc: 0.723204	valid's binary_logloss: 0.173849
# [148]	train's auc: 0.725311	train's binary_logloss: 0.173346	valid's auc: 0.723294	valid's binary_logloss: 0.173832
# [149]	train's auc: 0.725472	train's binary_logloss: 0.173325	valid's auc: 0.723418	valid's binary_logloss: 0.173815
# [150]	train's auc: 0.725555	train's binary_logloss: 0.173309	valid's auc: 0.723495	valid's binary_logloss: 0.173801
# [151]	train's auc: 0.725649	train's binary_logloss: 0.173289	valid's auc: 0.723567	valid's binary_logloss: 0.173786
# [152]	train's auc: 0.725848	train's binary_logloss: 0.173262	valid's auc: 0.723768	valid's binary_logloss: 0.17376
# [153]	train's auc: 0.72593	train's binary_logloss: 0.173239	valid's auc: 0.723843	valid's binary_logloss: 0.173739
# [154]	train's auc: 0.726062	train's binary_logloss: 0.173219	valid's auc: 0.723946	valid's binary_logloss: 0.173723
# [155]	train's auc: 0.726138	train's binary_logloss: 0.173204	valid's auc: 0.723986	valid's binary_logloss: 0.173713
# [156]	train's auc: 0.726218	train's binary_logloss: 0.173188	valid's auc: 0.724069	valid's binary_logloss: 0.173699
# [157]	train's auc: 0.726325	train's binary_logloss: 0.173171	valid's auc: 0.724128	valid's binary_logloss: 0.173686
# [158]	train's auc: 0.726379	train's binary_logloss: 0.173156	valid's auc: 0.724192	valid's binary_logloss: 0.173671
# [159]	train's auc: 0.726462	train's binary_logloss: 0.173139	valid's auc: 0.724277	valid's binary_logloss: 0.173654
# [160]	train's auc: 0.726529	train's binary_logloss: 0.173122	valid's auc: 0.724333	valid's binary_logloss: 0.173639
# [161]	train's auc: 0.726588	train's binary_logloss: 0.173107	valid's auc: 0.724369	valid's binary_logloss: 0.173629
# [162]	train's auc: 0.72668	train's binary_logloss: 0.173089	valid's auc: 0.724437	valid's binary_logloss: 0.173614
# [163]	train's auc: 0.726817	train's binary_logloss: 0.173067	valid's auc: 0.724533	valid's binary_logloss: 0.173595
# [164]	train's auc: 0.726925	train's binary_logloss: 0.173051	valid's auc: 0.724604	valid's binary_logloss: 0.173585
# [165]	train's auc: 0.72702	train's binary_logloss: 0.173035	valid's auc: 0.724676	valid's binary_logloss: 0.173572
# [166]	train's auc: 0.727173	train's binary_logloss: 0.173012	valid's auc: 0.724801	valid's binary_logloss: 0.173552
# [167]	train's auc: 0.727233	train's binary_logloss: 0.172998	valid's auc: 0.72487	valid's binary_logloss: 0.173539
# [168]	train's auc: 0.72729	train's binary_logloss: 0.172981	valid's auc: 0.724919	valid's binary_logloss: 0.173524
# [169]	train's auc: 0.727397	train's binary_logloss: 0.172965	valid's auc: 0.725005	valid's binary_logloss: 0.173511
# [170]	train's auc: 0.727482	train's binary_logloss: 0.172951	valid's auc: 0.725069	valid's binary_logloss: 0.173502
# [171]	train's auc: 0.727578	train's binary_logloss: 0.172935	valid's auc: 0.72513	valid's binary_logloss: 0.17349
# [172]	train's auc: 0.727658	train's binary_logloss: 0.172921	valid's auc: 0.72519	valid's binary_logloss: 0.17348
# [173]	train's auc: 0.727794	train's binary_logloss: 0.172901	valid's auc: 0.725289	valid's binary_logloss: 0.173466
# [174]	train's auc: 0.727888	train's binary_logloss: 0.172887	valid's auc: 0.725314	valid's binary_logloss: 0.173459
# [175]	train's auc: 0.728021	train's binary_logloss: 0.172859	valid's auc: 0.725427	valid's binary_logloss: 0.173436
# [176]	train's auc: 0.728136	train's binary_logloss: 0.172841	valid's auc: 0.72551	valid's binary_logloss: 0.173422
# [177]	train's auc: 0.728279	train's binary_logloss: 0.172817	valid's auc: 0.725637	valid's binary_logloss: 0.173399
# [178]	train's auc: 0.728358	train's binary_logloss: 0.172799	valid's auc: 0.72572	valid's binary_logloss: 0.173385
# [179]	train's auc: 0.728522	train's binary_logloss: 0.172775	valid's auc: 0.725859	valid's binary_logloss: 0.173364
# [180]	train's auc: 0.728616	train's binary_logloss: 0.17276	valid's auc: 0.725927	valid's binary_logloss: 0.173352
# [181]	train's auc: 0.728684	train's binary_logloss: 0.172745	valid's auc: 0.72597	valid's binary_logloss: 0.173342
# [182]	train's auc: 0.728813	train's binary_logloss: 0.17273	valid's auc: 0.726051	valid's binary_logloss: 0.173333
# [183]	train's auc: 0.728878	train's binary_logloss: 0.172716	valid's auc: 0.726099	valid's binary_logloss: 0.173322
# [184]	train's auc: 0.728976	train's binary_logloss: 0.172699	valid's auc: 0.726164	valid's binary_logloss: 0.173309
# [185]	train's auc: 0.729122	train's binary_logloss: 0.172677	valid's auc: 0.726326	valid's binary_logloss: 0.173288
# [186]	train's auc: 0.729224	train's binary_logloss: 0.172661	valid's auc: 0.726399	valid's binary_logloss: 0.173274
# [187]	train's auc: 0.729274	train's binary_logloss: 0.172646	valid's auc: 0.726439	valid's binary_logloss: 0.173263
# [188]	train's auc: 0.729381	train's binary_logloss: 0.172627	valid's auc: 0.726511	valid's binary_logloss: 0.173248
# [189]	train's auc: 0.729447	train's binary_logloss: 0.172614	valid's auc: 0.726563	valid's binary_logloss: 0.173237
# [190]	train's auc: 0.729549	train's binary_logloss: 0.172595	valid's auc: 0.726633	valid's binary_logloss: 0.173223
# [191]	train's auc: 0.729656	train's binary_logloss: 0.17258	valid's auc: 0.726709	valid's binary_logloss: 0.173212
# [192]	train's auc: 0.729726	train's binary_logloss: 0.172567	valid's auc: 0.726763	valid's binary_logloss: 0.173202
# [193]	train's auc: 0.729788	train's binary_logloss: 0.172556	valid's auc: 0.726806	valid's binary_logloss: 0.173193
# [194]	train's auc: 0.729843	train's binary_logloss: 0.172537	valid's auc: 0.726856	valid's binary_logloss: 0.173178
# [195]	train's auc: 0.729899	train's binary_logloss: 0.172524	valid's auc: 0.726894	valid's binary_logloss: 0.173168
# [196]	train's auc: 0.729987	train's binary_logloss: 0.172507	valid's auc: 0.726975	valid's binary_logloss: 0.173153
# [197]	train's auc: 0.730039	train's binary_logloss: 0.172493	valid's auc: 0.727004	valid's binary_logloss: 0.173145
# [198]	train's auc: 0.730089	train's binary_logloss: 0.172481	valid's auc: 0.727039	valid's binary_logloss: 0.173136
# [199]	train's auc: 0.730175	train's binary_logloss: 0.172467	valid's auc: 0.727103	valid's binary_logloss: 0.173126
# [200]	train's auc: 0.730259	train's binary_logloss: 0.172454	valid's auc: 0.727128	valid's binary_logloss: 0.173119
# [201]	train's auc: 0.730324	train's binary_logloss: 0.172441	valid's auc: 0.727163	valid's binary_logloss: 0.17311
# [202]	train's auc: 0.730383	train's binary_logloss: 0.172429	valid's auc: 0.727236	valid's binary_logloss: 0.173098
# [203]	train's auc: 0.730456	train's binary_logloss: 0.172416	valid's auc: 0.727294	valid's binary_logloss: 0.173089
# [204]	train's auc: 0.730529	train's binary_logloss: 0.172404	valid's auc: 0.727356	valid's binary_logloss: 0.17308
# [205]	train's auc: 0.730611	train's binary_logloss: 0.17239	valid's auc: 0.727415	valid's binary_logloss: 0.17307
# [206]	train's auc: 0.730686	train's binary_logloss: 0.172372	valid's auc: 0.727493	valid's binary_logloss: 0.173053
# [207]	train's auc: 0.730765	train's binary_logloss: 0.17236	valid's auc: 0.727529	valid's binary_logloss: 0.173047
# [208]	train's auc: 0.730828	train's binary_logloss: 0.172348	valid's auc: 0.727549	valid's binary_logloss: 0.173043
# [209]	train's auc: 0.730977	train's binary_logloss: 0.172327	valid's auc: 0.727676	valid's binary_logloss: 0.173026
# [210]	train's auc: 0.731032	train's binary_logloss: 0.172315	valid's auc: 0.727706	valid's binary_logloss: 0.173021
# [211]	train's auc: 0.731072	train's binary_logloss: 0.172304	valid's auc: 0.727713	valid's binary_logloss: 0.173015
# [212]	train's auc: 0.731153	train's binary_logloss: 0.172291	valid's auc: 0.727791	valid's binary_logloss: 0.173006
# [213]	train's auc: 0.731209	train's binary_logloss: 0.172281	valid's auc: 0.727826	valid's binary_logloss: 0.172997
# [214]	train's auc: 0.731292	train's binary_logloss: 0.172269	valid's auc: 0.727863	valid's binary_logloss: 0.172991
# [215]	train's auc: 0.731367	train's binary_logloss: 0.172259	valid's auc: 0.727886	valid's binary_logloss: 0.172986
# [216]	train's auc: 0.731428	train's binary_logloss: 0.172248	valid's auc: 0.727928	valid's binary_logloss: 0.172981
# [217]	train's auc: 0.731497	train's binary_logloss: 0.172235	valid's auc: 0.72798	valid's binary_logloss: 0.172972
# [218]	train's auc: 0.731575	train's binary_logloss: 0.17222	valid's auc: 0.728033	valid's binary_logloss: 0.172961
# [219]	train's auc: 0.731657	train's binary_logloss: 0.172207	valid's auc: 0.728062	valid's binary_logloss: 0.172954
# [220]	train's auc: 0.731728	train's binary_logloss: 0.172193	valid's auc: 0.728113	valid's binary_logloss: 0.172945
# [221]	train's auc: 0.731794	train's binary_logloss: 0.172178	valid's auc: 0.728175	valid's binary_logloss: 0.17293
# [222]	train's auc: 0.731836	train's binary_logloss: 0.172167	valid's auc: 0.7282	valid's binary_logloss: 0.172923
# [223]	train's auc: 0.731904	train's binary_logloss: 0.172154	valid's auc: 0.72824	valid's binary_logloss: 0.172915
# [224]	train's auc: 0.731985	train's binary_logloss: 0.172141	valid's auc: 0.728282	valid's binary_logloss: 0.172907
# [225]	train's auc: 0.732031	train's binary_logloss: 0.172129	valid's auc: 0.728316	valid's binary_logloss: 0.172899
# [226]	train's auc: 0.732099	train's binary_logloss: 0.172119	valid's auc: 0.728334	valid's binary_logloss: 0.172894
# [227]	train's auc: 0.732193	train's binary_logloss: 0.172102	valid's auc: 0.728407	valid's binary_logloss: 0.172881
# [228]	train's auc: 0.732289	train's binary_logloss: 0.17209	valid's auc: 0.728445	valid's binary_logloss: 0.172875
# [229]	train's auc: 0.732399	train's binary_logloss: 0.172075	valid's auc: 0.728535	valid's binary_logloss: 0.172862
# [230]	train's auc: 0.732471	train's binary_logloss: 0.172063	valid's auc: 0.728594	valid's binary_logloss: 0.172852
# [231]	train's auc: 0.732521	train's binary_logloss: 0.172053	valid's auc: 0.728626	valid's binary_logloss: 0.172845
# [232]	train's auc: 0.732574	train's binary_logloss: 0.17204	valid's auc: 0.728662	valid's binary_logloss: 0.172837
# [233]	train's auc: 0.732663	train's binary_logloss: 0.172028	valid's auc: 0.728688	valid's binary_logloss: 0.172833
# [234]	train's auc: 0.732723	train's binary_logloss: 0.172018	valid's auc: 0.72873	valid's binary_logloss: 0.172827
# [235]	train's auc: 0.732783	train's binary_logloss: 0.172006	valid's auc: 0.728763	valid's binary_logloss: 0.17282
# [236]	train's auc: 0.732847	train's binary_logloss: 0.171994	valid's auc: 0.728795	valid's binary_logloss: 0.172812
# [237]	train's auc: 0.732881	train's binary_logloss: 0.171984	valid's auc: 0.728809	valid's binary_logloss: 0.172808
# [238]	train's auc: 0.732951	train's binary_logloss: 0.171972	valid's auc: 0.728858	valid's binary_logloss: 0.172799
# [239]	train's auc: 0.73304	train's binary_logloss: 0.171954	valid's auc: 0.728919	valid's binary_logloss: 0.172785
# [240]	train's auc: 0.733113	train's binary_logloss: 0.171943	valid's auc: 0.728953	valid's binary_logloss: 0.17278
# [241]	train's auc: 0.733255	train's binary_logloss: 0.171921	valid's auc: 0.729091	valid's binary_logloss: 0.172759
# [242]	train's auc: 0.733333	train's binary_logloss: 0.171909	valid's auc: 0.729123	valid's binary_logloss: 0.172754
# [243]	train's auc: 0.733383	train's binary_logloss: 0.171898	valid's auc: 0.729159	valid's binary_logloss: 0.172746
# [244]	train's auc: 0.733469	train's binary_logloss: 0.171887	valid's auc: 0.729172	valid's binary_logloss: 0.172742
# [245]	train's auc: 0.733545	train's binary_logloss: 0.171877	valid's auc: 0.729223	valid's binary_logloss: 0.172737
# [246]	train's auc: 0.733597	train's binary_logloss: 0.171865	valid's auc: 0.729261	valid's binary_logloss: 0.172728
# [247]	train's auc: 0.733659	train's binary_logloss: 0.171848	valid's auc: 0.729319	valid's binary_logloss: 0.172715
# [248]	train's auc: 0.733712	train's binary_logloss: 0.171838	valid's auc: 0.729344	valid's binary_logloss: 0.172709
# [249]	train's auc: 0.733766	train's binary_logloss: 0.171827	valid's auc: 0.729387	valid's binary_logloss: 0.172702
# [250]	train's auc: 0.733839	train's binary_logloss: 0.171814	valid's auc: 0.729434	valid's binary_logloss: 0.172694
# [251]	train's auc: 0.73388	train's binary_logloss: 0.171805	valid's auc: 0.729454	valid's binary_logloss: 0.172689
# [252]	train's auc: 0.733952	train's binary_logloss: 0.171794	valid's auc: 0.729489	valid's binary_logloss: 0.172682
# [253]	train's auc: 0.734088	train's binary_logloss: 0.171774	valid's auc: 0.729631	valid's binary_logloss: 0.172664
# [254]	train's auc: 0.734144	train's binary_logloss: 0.171763	valid's auc: 0.729667	valid's binary_logloss: 0.172655
# [255]	train's auc: 0.73424	train's binary_logloss: 0.171749	valid's auc: 0.729746	valid's binary_logloss: 0.172645
# [256]	train's auc: 0.734294	train's binary_logloss: 0.171737	valid's auc: 0.729776	valid's binary_logloss: 0.172636
# [257]	train's auc: 0.734342	train's binary_logloss: 0.171726	valid's auc: 0.729797	valid's binary_logloss: 0.172632
# [258]	train's auc: 0.734399	train's binary_logloss: 0.171717	valid's auc: 0.729808	valid's binary_logloss: 0.172627
# [259]	train's auc: 0.734566	train's binary_logloss: 0.171695	valid's auc: 0.729928	valid's binary_logloss: 0.172611
# [260]	train's auc: 0.734607	train's binary_logloss: 0.171684	valid's auc: 0.729953	valid's binary_logloss: 0.172605
# [261]	train's auc: 0.734673	train's binary_logloss: 0.171673	valid's auc: 0.729999	valid's binary_logloss: 0.172597
# [262]	train's auc: 0.734699	train's binary_logloss: 0.171662	valid's auc: 0.730013	valid's binary_logloss: 0.17259
# [263]	train's auc: 0.734764	train's binary_logloss: 0.171652	valid's auc: 0.730032	valid's binary_logloss: 0.172586
# [264]	train's auc: 0.734825	train's binary_logloss: 0.171641	valid's auc: 0.730054	valid's binary_logloss: 0.17258
# [265]	train's auc: 0.73486	train's binary_logloss: 0.171631	valid's auc: 0.730081	valid's binary_logloss: 0.172574
# [266]	train's auc: 0.734934	train's binary_logloss: 0.171621	valid's auc: 0.7301	valid's binary_logloss: 0.17257
# [267]	train's auc: 0.734972	train's binary_logloss: 0.171613	valid's auc: 0.730129	valid's binary_logloss: 0.172565
# [268]	train's auc: 0.735038	train's binary_logloss: 0.171603	valid's auc: 0.730156	valid's binary_logloss: 0.172561
# [269]	train's auc: 0.7351	train's binary_logloss: 0.171594	valid's auc: 0.730176	valid's binary_logloss: 0.172556
# [270]	train's auc: 0.73517	train's binary_logloss: 0.171584	valid's auc: 0.730189	valid's binary_logloss: 0.172553
# [271]	train's auc: 0.73522	train's binary_logloss: 0.171575	valid's auc: 0.730226	valid's binary_logloss: 0.172548
# [272]	train's auc: 0.735273	train's binary_logloss: 0.171565	valid's auc: 0.730253	valid's binary_logloss: 0.172543
# [273]	train's auc: 0.735347	train's binary_logloss: 0.171553	valid's auc: 0.730281	valid's binary_logloss: 0.172538
# [274]	train's auc: 0.735442	train's binary_logloss: 0.17154	valid's auc: 0.730353	valid's binary_logloss: 0.172527
# [275]	train's auc: 0.735505	train's binary_logloss: 0.171529	valid's auc: 0.730366	valid's binary_logloss: 0.172524
# [276]	train's auc: 0.735548	train's binary_logloss: 0.17152	valid's auc: 0.730398	valid's binary_logloss: 0.172519
# [277]	train's auc: 0.735607	train's binary_logloss: 0.171511	valid's auc: 0.730432	valid's binary_logloss: 0.172514
# [278]	train's auc: 0.735656	train's binary_logloss: 0.171501	valid's auc: 0.730439	valid's binary_logloss: 0.172511
# [279]	train's auc: 0.73571	train's binary_logloss: 0.171492	valid's auc: 0.730435	valid's binary_logloss: 0.172509
# [280]	train's auc: 0.735781	train's binary_logloss: 0.171481	valid's auc: 0.730447	valid's binary_logloss: 0.172505
# [281]	train's auc: 0.735846	train's binary_logloss: 0.171471	valid's auc: 0.730467	valid's binary_logloss: 0.172501
# [282]	train's auc: 0.735903	train's binary_logloss: 0.171463	valid's auc: 0.730484	valid's binary_logloss: 0.172498
# [283]	train's auc: 0.735951	train's binary_logloss: 0.171453	valid's auc: 0.730493	valid's binary_logloss: 0.172494
# [284]	train's auc: 0.736058	train's binary_logloss: 0.171438	valid's auc: 0.730564	valid's binary_logloss: 0.172484
# [285]	train's auc: 0.73613	train's binary_logloss: 0.171429	valid's auc: 0.730573	valid's binary_logloss: 0.172483
# [286]	train's auc: 0.736219	train's binary_logloss: 0.171419	valid's auc: 0.730594	valid's binary_logloss: 0.172479
# [287]	train's auc: 0.736277	train's binary_logloss: 0.17141	valid's auc: 0.73062	valid's binary_logloss: 0.172475
# [288]	train's auc: 0.736338	train's binary_logloss: 0.1714	valid's auc: 0.730644	valid's binary_logloss: 0.172469
# [289]	train's auc: 0.736383	train's binary_logloss: 0.171392	valid's auc: 0.730666	valid's binary_logloss: 0.172465
# [290]	train's auc: 0.736429	train's binary_logloss: 0.171383	valid's auc: 0.730685	valid's binary_logloss: 0.172461
# [291]	train's auc: 0.736479	train's binary_logloss: 0.171372	valid's auc: 0.730726	valid's binary_logloss: 0.172451
# [292]	train's auc: 0.736541	train's binary_logloss: 0.171362	valid's auc: 0.73073	valid's binary_logloss: 0.172449
# [293]	train's auc: 0.736574	train's binary_logloss: 0.171354	valid's auc: 0.730744	valid's binary_logloss: 0.172444
# [294]	train's auc: 0.736625	train's binary_logloss: 0.171346	valid's auc: 0.730755	valid's binary_logloss: 0.172442
# [295]	train's auc: 0.736677	train's binary_logloss: 0.171337	valid's auc: 0.730762	valid's binary_logloss: 0.17244
# [296]	train's auc: 0.73677	train's binary_logloss: 0.171325	valid's auc: 0.730824	valid's binary_logloss: 0.172433
# [297]	train's auc: 0.7368	train's binary_logloss: 0.171316	valid's auc: 0.730847	valid's binary_logloss: 0.172427
# [298]	train's auc: 0.736846	train's binary_logloss: 0.171305	valid's auc: 0.730883	valid's binary_logloss: 0.17242
# [299]	train's auc: 0.736904	train's binary_logloss: 0.171297	valid's auc: 0.730892	valid's binary_logloss: 0.172418
# [300]	train's auc: 0.73698	train's binary_logloss: 0.171288	valid's auc: 0.730888	valid's binary_logloss: 0.172418
# [301]	train's auc: 0.737035	train's binary_logloss: 0.17128	valid's auc: 0.730894	valid's binary_logloss: 0.172416
# [302]	train's auc: 0.737068	train's binary_logloss: 0.171272	valid's auc: 0.730913	valid's binary_logloss: 0.172412
# [303]	train's auc: 0.737109	train's binary_logloss: 0.171263	valid's auc: 0.730928	valid's binary_logloss: 0.172408
# [304]	train's auc: 0.737176	train's binary_logloss: 0.171255	valid's auc: 0.730952	valid's binary_logloss: 0.172405
# [305]	train's auc: 0.737212	train's binary_logloss: 0.171246	valid's auc: 0.730964	valid's binary_logloss: 0.172401
# [306]	train's auc: 0.737307	train's binary_logloss: 0.171231	valid's auc: 0.731035	valid's binary_logloss: 0.17239
# [307]	train's auc: 0.737366	train's binary_logloss: 0.171222	valid's auc: 0.73105	valid's binary_logloss: 0.172387
# [308]	train's auc: 0.737451	train's binary_logloss: 0.171209	valid's auc: 0.731089	valid's binary_logloss: 0.172381
# [309]	train's auc: 0.737508	train's binary_logloss: 0.171201	valid's auc: 0.731093	valid's binary_logloss: 0.17238
# [310]	train's auc: 0.737575	train's binary_logloss: 0.171193	valid's auc: 0.731109	valid's binary_logloss: 0.172378
# [311]	train's auc: 0.737624	train's binary_logloss: 0.171185	valid's auc: 0.731131	valid's binary_logloss: 0.172374
# [312]	train's auc: 0.737665	train's binary_logloss: 0.171175	valid's auc: 0.731162	valid's binary_logloss: 0.172367
# [313]	train's auc: 0.737716	train's binary_logloss: 0.171166	valid's auc: 0.731191	valid's binary_logloss: 0.172361
# [314]	train's auc: 0.737795	train's binary_logloss: 0.171156	valid's auc: 0.731231	valid's binary_logloss: 0.172356
# [315]	train's auc: 0.737854	train's binary_logloss: 0.171148	valid's auc: 0.731242	valid's binary_logloss: 0.172355
# [316]	train's auc: 0.737904	train's binary_logloss: 0.171139	valid's auc: 0.731275	valid's binary_logloss: 0.17235
# [317]	train's auc: 0.737932	train's binary_logloss: 0.171129	valid's auc: 0.731292	valid's binary_logloss: 0.172343
# [318]	train's auc: 0.737964	train's binary_logloss: 0.171121	valid's auc: 0.731297	valid's binary_logloss: 0.17234
# [319]	train's auc: 0.738012	train's binary_logloss: 0.171112	valid's auc: 0.731321	valid's binary_logloss: 0.172336
# [320]	train's auc: 0.738113	train's binary_logloss: 0.1711	valid's auc: 0.73137	valid's binary_logloss: 0.172329
# [321]	train's auc: 0.738141	train's binary_logloss: 0.171092	valid's auc: 0.731387	valid's binary_logloss: 0.172326
# [322]	train's auc: 0.738209	train's binary_logloss: 0.171084	valid's auc: 0.731425	valid's binary_logloss: 0.172321
# [323]	train's auc: 0.738249	train's binary_logloss: 0.171077	valid's auc: 0.731427	valid's binary_logloss: 0.172321
# [324]	train's auc: 0.738306	train's binary_logloss: 0.171067	valid's auc: 0.731448	valid's binary_logloss: 0.172317
# [325]	train's auc: 0.738345	train's binary_logloss: 0.171059	valid's auc: 0.731451	valid's binary_logloss: 0.172314
# [326]	train's auc: 0.738381	train's binary_logloss: 0.17105	valid's auc: 0.731463	valid's binary_logloss: 0.172311
# [327]	train's auc: 0.738424	train's binary_logloss: 0.17104	valid's auc: 0.731475	valid's binary_logloss: 0.172307
# [328]	train's auc: 0.738489	train's binary_logloss: 0.171032	valid's auc: 0.731484	valid's binary_logloss: 0.172305
# [329]	train's auc: 0.738534	train's binary_logloss: 0.171021	valid's auc: 0.731507	valid's binary_logloss: 0.172299
# [330]	train's auc: 0.738573	train's binary_logloss: 0.171013	valid's auc: 0.73152	valid's binary_logloss: 0.172296
# [331]	train's auc: 0.738688	train's binary_logloss: 0.171	valid's auc: 0.731603	valid's binary_logloss: 0.172288
# [332]	train's auc: 0.738743	train's binary_logloss: 0.170992	valid's auc: 0.731626	valid's binary_logloss: 0.172285
# [333]	train's auc: 0.738789	train's binary_logloss: 0.170982	valid's auc: 0.731644	valid's binary_logloss: 0.172281
# [334]	train's auc: 0.738839	train's binary_logloss: 0.170975	valid's auc: 0.731644	valid's binary_logloss: 0.172279
# [335]	train's auc: 0.738899	train's binary_logloss: 0.170966	valid's auc: 0.731656	valid's binary_logloss: 0.172278
# [336]	train's auc: 0.738946	train's binary_logloss: 0.170958	valid's auc: 0.731659	valid's binary_logloss: 0.172277
# [337]	train's auc: 0.738997	train's binary_logloss: 0.17095	valid's auc: 0.731667	valid's binary_logloss: 0.172273
# [338]	train's auc: 0.739049	train's binary_logloss: 0.170941	valid's auc: 0.731684	valid's binary_logloss: 0.17227
# [339]	train's auc: 0.739135	train's binary_logloss: 0.170933	valid's auc: 0.731717	valid's binary_logloss: 0.172266
# [340]	train's auc: 0.739202	train's binary_logloss: 0.170925	valid's auc: 0.731716	valid's binary_logloss: 0.172266
# [341]	train's auc: 0.739265	train's binary_logloss: 0.170916	valid's auc: 0.731724	valid's binary_logloss: 0.172264
# [342]	train's auc: 0.739314	train's binary_logloss: 0.170908	valid's auc: 0.731735	valid's binary_logloss: 0.172261
# [343]	train's auc: 0.739358	train's binary_logloss: 0.1709	valid's auc: 0.731752	valid's binary_logloss: 0.172258
# [344]	train's auc: 0.739412	train's binary_logloss: 0.170892	valid's auc: 0.731767	valid's binary_logloss: 0.172255
# [345]	train's auc: 0.73946	train's binary_logloss: 0.170885	valid's auc: 0.731777	valid's binary_logloss: 0.172252
# [346]	train's auc: 0.739514	train's binary_logloss: 0.170878	valid's auc: 0.731778	valid's binary_logloss: 0.17225
# [347]	train's auc: 0.739546	train's binary_logloss: 0.170871	valid's auc: 0.731779	valid's binary_logloss: 0.172249
# [348]	train's auc: 0.739594	train's binary_logloss: 0.170863	valid's auc: 0.731784	valid's binary_logloss: 0.172248
# [349]	train's auc: 0.739658	train's binary_logloss: 0.170855	valid's auc: 0.731807	valid's binary_logloss: 0.172245
# [350]	train's auc: 0.739711	train's binary_logloss: 0.170846	valid's auc: 0.731821	valid's binary_logloss: 0.172242
# [351]	train's auc: 0.73979	train's binary_logloss: 0.170836	valid's auc: 0.731861	valid's binary_logloss: 0.172238
# [352]	train's auc: 0.739833	train's binary_logloss: 0.170827	valid's auc: 0.731892	valid's binary_logloss: 0.172231
# [353]	train's auc: 0.739858	train's binary_logloss: 0.170818	valid's auc: 0.731902	valid's binary_logloss: 0.172225
# [354]	train's auc: 0.739907	train's binary_logloss: 0.170809	valid's auc: 0.731916	valid's binary_logloss: 0.172222
# [355]	train's auc: 0.73997	train's binary_logloss: 0.1708	valid's auc: 0.731933	valid's binary_logloss: 0.172219
# [356]	train's auc: 0.740031	train's binary_logloss: 0.170791	valid's auc: 0.731936	valid's binary_logloss: 0.172217
# [357]	train's auc: 0.740074	train's binary_logloss: 0.170783	valid's auc: 0.73194	valid's binary_logloss: 0.172216
# [358]	train's auc: 0.740119	train's binary_logloss: 0.170774	valid's auc: 0.731962	valid's binary_logloss: 0.172212
# [359]	train's auc: 0.74018	train's binary_logloss: 0.170766	valid's auc: 0.731981	valid's binary_logloss: 0.172209
# [360]	train's auc: 0.740211	train's binary_logloss: 0.170758	valid's auc: 0.731995	valid's binary_logloss: 0.172205
# [361]	train's auc: 0.740299	train's binary_logloss: 0.170744	valid's auc: 0.732038	valid's binary_logloss: 0.172197
# [362]	train's auc: 0.740345	train's binary_logloss: 0.170736	valid's auc: 0.732048	valid's binary_logloss: 0.172194
# [363]	train's auc: 0.740396	train's binary_logloss: 0.170729	valid's auc: 0.732052	valid's binary_logloss: 0.172193
# [364]	train's auc: 0.74045	train's binary_logloss: 0.170722	valid's auc: 0.732063	valid's binary_logloss: 0.172191
# [365]	train's auc: 0.740483	train's binary_logloss: 0.170714	valid's auc: 0.732065	valid's binary_logloss: 0.172189
# [366]	train's auc: 0.740541	train's binary_logloss: 0.170707	valid's auc: 0.73207	valid's binary_logloss: 0.172188
# [367]	train's auc: 0.740585	train's binary_logloss: 0.170699	valid's auc: 0.732091	valid's binary_logloss: 0.172184
# [368]	train's auc: 0.740631	train's binary_logloss: 0.170692	valid's auc: 0.73209	valid's binary_logloss: 0.172184
# [369]	train's auc: 0.740668	train's binary_logloss: 0.170685	valid's auc: 0.732089	valid's binary_logloss: 0.172182
# [370]	train's auc: 0.740734	train's binary_logloss: 0.170676	valid's auc: 0.732103	valid's binary_logloss: 0.17218
# [371]	train's auc: 0.740773	train's binary_logloss: 0.170668	valid's auc: 0.732135	valid's binary_logloss: 0.172175
# [372]	train's auc: 0.740819	train's binary_logloss: 0.170661	valid's auc: 0.732143	valid's binary_logloss: 0.172174
# [373]	train's auc: 0.740866	train's binary_logloss: 0.170654	valid's auc: 0.732149	valid's binary_logloss: 0.172172
# [374]	train's auc: 0.740912	train's binary_logloss: 0.170644	valid's auc: 0.732164	valid's binary_logloss: 0.17217
# [375]	train's auc: 0.740973	train's binary_logloss: 0.170635	valid's auc: 0.732183	valid's binary_logloss: 0.172166
# [376]	train's auc: 0.741016	train's binary_logloss: 0.170627	valid's auc: 0.732194	valid's binary_logloss: 0.172165
# [377]	train's auc: 0.741055	train's binary_logloss: 0.17062	valid's auc: 0.7322	valid's binary_logloss: 0.172163
# [378]	train's auc: 0.741099	train's binary_logloss: 0.170613	valid's auc: 0.732209	valid's binary_logloss: 0.172162
# [379]	train's auc: 0.741167	train's binary_logloss: 0.170603	valid's auc: 0.732235	valid's binary_logloss: 0.172157
# [380]	train's auc: 0.741209	train's binary_logloss: 0.170594	valid's auc: 0.732249	valid's binary_logloss: 0.172153
# [381]	train's auc: 0.741274	train's binary_logloss: 0.170585	valid's auc: 0.732274	valid's binary_logloss: 0.172151
# [382]	train's auc: 0.741344	train's binary_logloss: 0.170576	valid's auc: 0.73227	valid's binary_logloss: 0.17215
# [383]	train's auc: 0.741386	train's binary_logloss: 0.170569	valid's auc: 0.732269	valid's binary_logloss: 0.172149
# [384]	train's auc: 0.74143	train's binary_logloss: 0.170562	valid's auc: 0.732279	valid's binary_logloss: 0.172147
# [385]	train's auc: 0.741481	train's binary_logloss: 0.170554	valid's auc: 0.732275	valid's binary_logloss: 0.172148
# [386]	train's auc: 0.741538	train's binary_logloss: 0.170548	valid's auc: 0.732297	valid's binary_logloss: 0.172146
# [387]	train's auc: 0.741582	train's binary_logloss: 0.17054	valid's auc: 0.732309	valid's binary_logloss: 0.172145
# [388]	train's auc: 0.741619	train's binary_logloss: 0.170532	valid's auc: 0.732332	valid's binary_logloss: 0.172139
# [389]	train's auc: 0.741655	train's binary_logloss: 0.170525	valid's auc: 0.732336	valid's binary_logloss: 0.172137
# [390]	train's auc: 0.741686	train's binary_logloss: 0.170518	valid's auc: 0.732343	valid's binary_logloss: 0.172135
# [391]	train's auc: 0.741722	train's binary_logloss: 0.170511	valid's auc: 0.732354	valid's binary_logloss: 0.172133
# [392]	train's auc: 0.741773	train's binary_logloss: 0.170504	valid's auc: 0.73236	valid's binary_logloss: 0.172132
# [393]	train's auc: 0.741823	train's binary_logloss: 0.170496	valid's auc: 0.732379	valid's binary_logloss: 0.172129
# [394]	train's auc: 0.741952	train's binary_logloss: 0.170481	valid's auc: 0.732486	valid's binary_logloss: 0.172117
# [395]	train's auc: 0.74201	train's binary_logloss: 0.170473	valid's auc: 0.732508	valid's binary_logloss: 0.172115
# [396]	train's auc: 0.742065	train's binary_logloss: 0.170466	valid's auc: 0.732508	valid's binary_logloss: 0.172115
# [397]	train's auc: 0.742093	train's binary_logloss: 0.170458	valid's auc: 0.732523	valid's binary_logloss: 0.172111
# [398]	train's auc: 0.74211	train's binary_logloss: 0.170451	valid's auc: 0.732521	valid's binary_logloss: 0.17211
# [399]	train's auc: 0.742161	train's binary_logloss: 0.170444	valid's auc: 0.732531	valid's binary_logloss: 0.172108
# [400]	train's auc: 0.742231	train's binary_logloss: 0.170435	valid's auc: 0.73254	valid's binary_logloss: 0.172106
# [401]	train's auc: 0.742261	train's binary_logloss: 0.170427	valid's auc: 0.732549	valid's binary_logloss: 0.172103
# [402]	train's auc: 0.742304	train's binary_logloss: 0.170418	valid's auc: 0.732565	valid's binary_logloss: 0.172097
# [403]	train's auc: 0.742354	train's binary_logloss: 0.170411	valid's auc: 0.732579	valid's binary_logloss: 0.172096
# [404]	train's auc: 0.742394	train's binary_logloss: 0.170403	valid's auc: 0.732585	valid's binary_logloss: 0.172094
# [405]	train's auc: 0.742416	train's binary_logloss: 0.170396	valid's auc: 0.732601	valid's binary_logloss: 0.17209
# [406]	train's auc: 0.742441	train's binary_logloss: 0.170389	valid's auc: 0.732613	valid's binary_logloss: 0.172087
# [407]	train's auc: 0.74249	train's binary_logloss: 0.170382	valid's auc: 0.732614	valid's binary_logloss: 0.172087
# [408]	train's auc: 0.742545	train's binary_logloss: 0.170375	valid's auc: 0.732624	valid's binary_logloss: 0.172086
# [409]	train's auc: 0.742587	train's binary_logloss: 0.170367	valid's auc: 0.732641	valid's binary_logloss: 0.172081
# [410]	train's auc: 0.742635	train's binary_logloss: 0.17036	valid's auc: 0.732643	valid's binary_logloss: 0.172081
# ...
# [2125]	train's auc: 0.796504	train's binary_logloss: 0.16126	valid's auc: 0.737723	valid's binary_logloss: 0.17091
# [2126]	train's auc: 0.796527	train's binary_logloss: 0.161255	valid's auc: 0.737727	valid's binary_logloss: 0.170909
# [2127]	train's auc: 0.79655	train's binary_logloss: 0.161251	valid's auc: 0.737719	valid's binary_logloss: 0.17091
# [2128]	train's auc: 0.796576	train's binary_logloss: 0.161247	valid's auc: 0.737724	valid's binary_logloss: 0.17091
# [2129]	train's auc: 0.796592	train's binary_logloss: 0.161242	valid's auc: 0.737723	valid's binary_logloss: 0.17091
# [2130]	train's auc: 0.796625	train's binary_logloss: 0.161237	valid's auc: 0.737727	valid's binary_logloss: 0.17091
# [2131]	train's auc: 0.796634	train's binary_logloss: 0.161234	valid's auc: 0.737728	valid's binary_logloss: 0.17091
# [2132]	train's auc: 0.796653	train's binary_logloss: 0.16123	valid's auc: 0.737723	valid's binary_logloss: 0.17091
# [2133]	train's auc: 0.796672	train's binary_logloss: 0.161226	valid's auc: 0.737724	valid's binary_logloss: 0.17091
# [2134]	train's auc: 0.796697	train's binary_logloss: 0.161222	valid's auc: 0.737726	valid's binary_logloss: 0.17091
# [2135]	train's auc: 0.796728	train's binary_logloss: 0.161216	valid's auc: 0.737728	valid's binary_logloss: 0.170911
# [2136]	train's auc: 0.79676	train's binary_logloss: 0.161212	valid's auc: 0.737729	valid's binary_logloss: 0.170911
# [2137]	train's auc: 0.796776	train's binary_logloss: 0.161207	valid's auc: 0.737744	valid's binary_logloss: 0.170909
# [2138]	train's auc: 0.796794	train's binary_logloss: 0.161204	valid's auc: 0.737733	valid's binary_logloss: 0.17091
# [2139]	train's auc: 0.796844	train's binary_logloss: 0.161194	valid's auc: 0.737793	valid's binary_logloss: 0.170903
# [2140]	train's auc: 0.796899	train's binary_logloss: 0.161185	valid's auc: 0.737797	valid's binary_logloss: 0.170901
# [2141]	train's auc: 0.796911	train's binary_logloss: 0.161182	valid's auc: 0.737796	valid's binary_logloss: 0.170901
# [2142]	train's auc: 0.796955	train's binary_logloss: 0.161176	valid's auc: 0.737796	valid's binary_logloss: 0.170901
# [2143]	train's auc: 0.796987	train's binary_logloss: 0.161172	valid's auc: 0.737787	valid's binary_logloss: 0.170902
# [2144]	train's auc: 0.797005	train's binary_logloss: 0.161168	valid's auc: 0.737785	valid's binary_logloss: 0.170902
# [2145]	train's auc: 0.797029	train's binary_logloss: 0.161164	valid's auc: 0.737783	valid's binary_logloss: 0.170902
# [2146]	train's auc: 0.797045	train's binary_logloss: 0.16116	valid's auc: 0.737784	valid's binary_logloss: 0.170902
# [2147]	train's auc: 0.797074	train's binary_logloss: 0.161154	valid's auc: 0.737786	valid's binary_logloss: 0.170902
# [2148]	train's auc: 0.797096	train's binary_logloss: 0.16115	valid's auc: 0.73779	valid's binary_logloss: 0.170902
# [2149]	train's auc: 0.797116	train's binary_logloss: 0.161146	valid's auc: 0.737792	valid's binary_logloss: 0.170901
# [2150]	train's auc: 0.797143	train's binary_logloss: 0.161142	valid's auc: 0.737787	valid's binary_logloss: 0.170901
# [2151]	train's auc: 0.797182	train's binary_logloss: 0.161135	valid's auc: 0.737787	valid's binary_logloss: 0.1709
# [2152]	train's auc: 0.7972	train's binary_logloss: 0.16113	valid's auc: 0.737789	valid's binary_logloss: 0.1709
# [2153]	train's auc: 0.797223	train's binary_logloss: 0.161126	valid's auc: 0.737787	valid's binary_logloss: 0.1709
# [2154]	train's auc: 0.797266	train's binary_logloss: 0.16112	valid's auc: 0.737795	valid's binary_logloss: 0.170899
# [2155]	train's auc: 0.797295	train's binary_logloss: 0.161115	valid's auc: 0.737794	valid's binary_logloss: 0.1709
# [2156]	train's auc: 0.797328	train's binary_logloss: 0.16111	valid's auc: 0.737797	valid's binary_logloss: 0.170899
# [2157]	train's auc: 0.797366	train's binary_logloss: 0.161105	valid's auc: 0.737798	valid's binary_logloss: 0.170899
# [2158]	train's auc: 0.797378	train's binary_logloss: 0.161102	valid's auc: 0.737797	valid's binary_logloss: 0.170899
# [2159]	train's auc: 0.797394	train's binary_logloss: 0.161098	valid's auc: 0.737798	valid's binary_logloss: 0.1709
# [2160]	train's auc: 0.797423	train's binary_logloss: 0.161094	valid's auc: 0.737792	valid's binary_logloss: 0.1709
# [2161]	train's auc: 0.797445	train's binary_logloss: 0.16109	valid's auc: 0.737788	valid's binary_logloss: 0.170901
# [2162]	train's auc: 0.797463	train's binary_logloss: 0.161086	valid's auc: 0.737788	valid's binary_logloss: 0.1709
# [2163]	train's auc: 0.797488	train's binary_logloss: 0.161083	valid's auc: 0.737788	valid's binary_logloss: 0.170899
# [2164]	train's auc: 0.797509	train's binary_logloss: 0.161079	valid's auc: 0.737788	valid's binary_logloss: 0.170899
# [2165]	train's auc: 0.797531	train's binary_logloss: 0.161075	valid's auc: 0.737784	valid's binary_logloss: 0.1709
# [2166]	train's auc: 0.79755	train's binary_logloss: 0.161072	valid's auc: 0.737783	valid's binary_logloss: 0.1709
# [2167]	train's auc: 0.797566	train's binary_logloss: 0.161069	valid's auc: 0.737782	valid's binary_logloss: 0.1709
# [2168]	train's auc: 0.797581	train's binary_logloss: 0.161066	valid's auc: 0.737778	valid's binary_logloss: 0.170901
# [2169]	train's auc: 0.797598	train's binary_logloss: 0.161062	valid's auc: 0.737778	valid's binary_logloss: 0.1709
# [2170]	train's auc: 0.797615	train's binary_logloss: 0.161058	valid's auc: 0.737773	valid's binary_logloss: 0.170901
# [2171]	train's auc: 0.797633	train's binary_logloss: 0.161054	valid's auc: 0.737765	valid's binary_logloss: 0.170902
# [2172]	train's auc: 0.797643	train's binary_logloss: 0.161051	valid's auc: 0.73776	valid's binary_logloss: 0.170903
# [2173]	train's auc: 0.797658	train's binary_logloss: 0.161047	valid's auc: 0.737755	valid's binary_logloss: 0.170903
# [2174]	train's auc: 0.797664	train's binary_logloss: 0.161043	valid's auc: 0.737759	valid's binary_logloss: 0.170901
# [2175]	train's auc: 0.797686	train's binary_logloss: 0.161036	valid's auc: 0.737767	valid's binary_logloss: 0.170899
# [2176]	train's auc: 0.797699	train's binary_logloss: 0.161032	valid's auc: 0.737763	valid's binary_logloss: 0.170898
# [2177]	train's auc: 0.797707	train's binary_logloss: 0.161029	valid's auc: 0.73776	valid's binary_logloss: 0.170898
# [2178]	train's auc: 0.79773	train's binary_logloss: 0.161025	valid's auc: 0.737764	valid's binary_logloss: 0.170898
# [2179]	train's auc: 0.797757	train's binary_logloss: 0.16102	valid's auc: 0.737757	valid's binary_logloss: 0.170899
# [2180]	train's auc: 0.797776	train's binary_logloss: 0.161016	valid's auc: 0.737756	valid's binary_logloss: 0.170899
# [2181]	train's auc: 0.797801	train's binary_logloss: 0.161012	valid's auc: 0.737755	valid's binary_logloss: 0.170899
# [2182]	train's auc: 0.797821	train's binary_logloss: 0.161007	valid's auc: 0.737752	valid's binary_logloss: 0.1709
# [2183]	train's auc: 0.797856	train's binary_logloss: 0.161001	valid's auc: 0.737749	valid's binary_logloss: 0.1709
# [2184]	train's auc: 0.797884	train's binary_logloss: 0.160996	valid's auc: 0.737758	valid's binary_logloss: 0.170898
# [2185]	train's auc: 0.797915	train's binary_logloss: 0.160992	valid's auc: 0.73775	valid's binary_logloss: 0.170899
# [2186]	train's auc: 0.797944	train's binary_logloss: 0.160987	valid's auc: 0.737747	valid's binary_logloss: 0.1709
# [2187]	train's auc: 0.797977	train's binary_logloss: 0.160982	valid's auc: 0.737748	valid's binary_logloss: 0.170899
# [2188]	train's auc: 0.797999	train's binary_logloss: 0.160978	valid's auc: 0.737746	valid's binary_logloss: 0.170899
# [2189]	train's auc: 0.79802	train's binary_logloss: 0.160975	valid's auc: 0.737742	valid's binary_logloss: 0.1709
# [2190]	train's auc: 0.798041	train's binary_logloss: 0.160971	valid's auc: 0.737741	valid's binary_logloss: 0.1709
# [2191]	train's auc: 0.798074	train's binary_logloss: 0.160966	valid's auc: 0.737736	valid's binary_logloss: 0.1709
# [2192]	train's auc: 0.798101	train's binary_logloss: 0.160962	valid's auc: 0.737747	valid's binary_logloss: 0.170899
# [2193]	train's auc: 0.79812	train's binary_logloss: 0.160958	valid's auc: 0.737751	valid's binary_logloss: 0.170899
# [2194]	train's auc: 0.798137	train's binary_logloss: 0.160955	valid's auc: 0.73775	valid's binary_logloss: 0.170898
# [2195]	train's auc: 0.798153	train's binary_logloss: 0.160951	valid's auc: 0.73775	valid's binary_logloss: 0.170898
# [2196]	train's auc: 0.798188	train's binary_logloss: 0.160946	valid's auc: 0.737749	valid's binary_logloss: 0.170898
# [2197]	train's auc: 0.798206	train's binary_logloss: 0.160943	valid's auc: 0.737751	valid's binary_logloss: 0.170897
# [2198]	train's auc: 0.798242	train's binary_logloss: 0.160936	valid's auc: 0.737745	valid's binary_logloss: 0.170898
# [2199]	train's auc: 0.79826	train's binary_logloss: 0.160933	valid's auc: 0.737745	valid's binary_logloss: 0.170898
# [2200]	train's auc: 0.79828	train's binary_logloss: 0.160929	valid's auc: 0.73775	valid's binary_logloss: 0.170897
# [2201]	train's auc: 0.798301	train's binary_logloss: 0.160926	valid's auc: 0.737747	valid's binary_logloss: 0.170897
# [2202]	train's auc: 0.798326	train's binary_logloss: 0.160922	valid's auc: 0.737744	valid's binary_logloss: 0.170897
# [2203]	train's auc: 0.798339	train's binary_logloss: 0.160919	valid's auc: 0.737746	valid's binary_logloss: 0.170896
# [2204]	train's auc: 0.798355	train's binary_logloss: 0.160916	valid's auc: 0.737739	valid's binary_logloss: 0.170897
# [2205]	train's auc: 0.798383	train's binary_logloss: 0.160912	valid's auc: 0.737752	valid's binary_logloss: 0.170895
# [2206]	train's auc: 0.798407	train's binary_logloss: 0.160907	valid's auc: 0.737752	valid's binary_logloss: 0.170895
# [2207]	train's auc: 0.798422	train's binary_logloss: 0.160903	valid's auc: 0.737758	valid's binary_logloss: 0.170895
# [2208]	train's auc: 0.798443	train's binary_logloss: 0.1609	valid's auc: 0.737756	valid's binary_logloss: 0.170895
# [2209]	train's auc: 0.79847	train's binary_logloss: 0.160896	valid's auc: 0.737751	valid's binary_logloss: 0.170895
# [2210]	train's auc: 0.798483	train's binary_logloss: 0.160892	valid's auc: 0.737748	valid's binary_logloss: 0.170895
# [2211]	train's auc: 0.798507	train's binary_logloss: 0.160889	valid's auc: 0.737746	valid's binary_logloss: 0.170896
# [2212]	train's auc: 0.798524	train's binary_logloss: 0.160885	valid's auc: 0.73775	valid's binary_logloss: 0.170895
# [2213]	train's auc: 0.798546	train's binary_logloss: 0.160882	valid's auc: 0.737755	valid's binary_logloss: 0.170895
# [2214]	train's auc: 0.798568	train's binary_logloss: 0.160877	valid's auc: 0.737755	valid's binary_logloss: 0.170894
# [2215]	train's auc: 0.798585	train's binary_logloss: 0.160874	valid's auc: 0.737757	valid's binary_logloss: 0.170895
# [2216]	train's auc: 0.798613	train's binary_logloss: 0.16087	valid's auc: 0.737752	valid's binary_logloss: 0.170895
# [2217]	train's auc: 0.798627	train's binary_logloss: 0.160866	valid's auc: 0.737751	valid's binary_logloss: 0.170895
# [2218]	train's auc: 0.798642	train's binary_logloss: 0.160862	valid's auc: 0.737756	valid's binary_logloss: 0.170895
# [2219]	train's auc: 0.798671	train's binary_logloss: 0.160858	valid's auc: 0.73776	valid's binary_logloss: 0.170894
# [2220]	train's auc: 0.798692	train's binary_logloss: 0.160855	valid's auc: 0.737755	valid's binary_logloss: 0.170894
# [2221]	train's auc: 0.798711	train's binary_logloss: 0.160851	valid's auc: 0.737754	valid's binary_logloss: 0.170894
# [2222]	train's auc: 0.798728	train's binary_logloss: 0.160848	valid's auc: 0.737761	valid's binary_logloss: 0.170894
# [2223]	train's auc: 0.798742	train's binary_logloss: 0.160844	valid's auc: 0.737758	valid's binary_logloss: 0.170894
# [2224]	train's auc: 0.798761	train's binary_logloss: 0.160841	valid's auc: 0.737757	valid's binary_logloss: 0.170894
# [2225]	train's auc: 0.798785	train's binary_logloss: 0.160837	valid's auc: 0.737751	valid's binary_logloss: 0.170895
# [2226]	train's auc: 0.798797	train's binary_logloss: 0.160834	valid's auc: 0.737752	valid's binary_logloss: 0.170894
# [2227]	train's auc: 0.798835	train's binary_logloss: 0.160829	valid's auc: 0.737746	valid's binary_logloss: 0.170894
# [2228]	train's auc: 0.798854	train's binary_logloss: 0.160825	valid's auc: 0.737743	valid's binary_logloss: 0.170894
# [2229]	train's auc: 0.798877	train's binary_logloss: 0.160822	valid's auc: 0.737745	valid's binary_logloss: 0.170894
# [2230]	train's auc: 0.798902	train's binary_logloss: 0.160818	valid's auc: 0.737748	valid's binary_logloss: 0.170894
# [2231]	train's auc: 0.79892	train's binary_logloss: 0.160814	valid's auc: 0.737745	valid's binary_logloss: 0.170894
# [2232]	train's auc: 0.798945	train's binary_logloss: 0.160811	valid's auc: 0.737741	valid's binary_logloss: 0.170894
# [2233]	train's auc: 0.799008	train's binary_logloss: 0.160802	valid's auc: 0.737747	valid's binary_logloss: 0.170892
# [2234]	train's auc: 0.799067	train's binary_logloss: 0.160791	valid's auc: 0.737796	valid's binary_logloss: 0.170886
# [2235]	train's auc: 0.799086	train's binary_logloss: 0.160787	valid's auc: 0.73779	valid's binary_logloss: 0.170886
# [2236]	train's auc: 0.799109	train's binary_logloss: 0.160784	valid's auc: 0.737785	valid's binary_logloss: 0.170886
# [2237]	train's auc: 0.799129	train's binary_logloss: 0.16078	valid's auc: 0.737781	valid's binary_logloss: 0.170887
# [2238]	train's auc: 0.79915	train's binary_logloss: 0.160776	valid's auc: 0.737775	valid's binary_logloss: 0.170888
# [2239]	train's auc: 0.799172	train's binary_logloss: 0.160772	valid's auc: 0.737771	valid's binary_logloss: 0.170888
# [2240]	train's auc: 0.799186	train's binary_logloss: 0.160768	valid's auc: 0.737768	valid's binary_logloss: 0.170888
# [2241]	train's auc: 0.799206	train's binary_logloss: 0.160764	valid's auc: 0.737776	valid's binary_logloss: 0.170887
# [2242]	train's auc: 0.799222	train's binary_logloss: 0.16076	valid's auc: 0.737774	valid's binary_logloss: 0.170887
# [2243]	train's auc: 0.799242	train's binary_logloss: 0.160756	valid's auc: 0.737776	valid's binary_logloss: 0.170887
# [2244]	train's auc: 0.79926	train's binary_logloss: 0.160753	valid's auc: 0.737775	valid's binary_logloss: 0.170887
# [2245]	train's auc: 0.799279	train's binary_logloss: 0.160749	valid's auc: 0.737776	valid's binary_logloss: 0.170887
# [2246]	train's auc: 0.799302	train's binary_logloss: 0.160745	valid's auc: 0.737773	valid's binary_logloss: 0.170887
# [2247]	train's auc: 0.799325	train's binary_logloss: 0.16074	valid's auc: 0.737773	valid's binary_logloss: 0.170887
# [2248]	train's auc: 0.799344	train's binary_logloss: 0.160737	valid's auc: 0.737768	valid's binary_logloss: 0.170888
# [2249]	train's auc: 0.799365	train's binary_logloss: 0.160733	valid's auc: 0.737773	valid's binary_logloss: 0.170888
# [2250]	train's auc: 0.799382	train's binary_logloss: 0.16073	valid's auc: 0.737766	valid's binary_logloss: 0.170889
# [2251]	train's auc: 0.799402	train's binary_logloss: 0.160727	valid's auc: 0.737762	valid's binary_logloss: 0.170889
# [2252]	train's auc: 0.799426	train's binary_logloss: 0.160722	valid's auc: 0.737763	valid's binary_logloss: 0.170888
# [2253]	train's auc: 0.79946	train's binary_logloss: 0.160715	valid's auc: 0.737764	valid's binary_logloss: 0.170888
# [2254]	train's auc: 0.799477	train's binary_logloss: 0.160711	valid's auc: 0.737767	valid's binary_logloss: 0.170888
# [2255]	train's auc: 0.799503	train's binary_logloss: 0.160707	valid's auc: 0.737783	valid's binary_logloss: 0.170887
# [2256]	train's auc: 0.799542	train's binary_logloss: 0.1607	valid's auc: 0.737789	valid's binary_logloss: 0.170886
# [2257]	train's auc: 0.799563	train's binary_logloss: 0.160697	valid's auc: 0.737787	valid's binary_logloss: 0.170886
# [2258]	train's auc: 0.799607	train's binary_logloss: 0.16069	valid's auc: 0.737778	valid's binary_logloss: 0.170887
# [2259]	train's auc: 0.799632	train's binary_logloss: 0.160687	valid's auc: 0.737774	valid's binary_logloss: 0.170887
# Early stopping, best iteration is:
# [2159]	train's auc: 0.797394	train's binary_logloss: 0.161098	valid's auc: 0.737798	valid's binary_logloss: 0.1709
# LGBMClassifier(n_estimators=10000, silent=False, subsample_freq=1)

# %%
feat_imp = pd.Series(clf.feature_importances_)
feat_imp = feat_imp[feat_imp > 0]

imp_col_lst = list(feat_imp.sort_values(ascending=False).index)

pd.Series(imp_col_lst).to_csv(data_prep_dir + 'feature_importance.csv',index=False)

print('There are {} features with importance > 0.'.format(len(imp_col_lst)))
# Out:
# There are 11762 features with importance > 0.

# %%
n = clf.best_iteration_
base_loss = clf.best_score_['valid']['binary_logloss']
base_auc = clf.best_score_['valid']['auc']
print('Base loss is', base_loss, 'and AUC is', base_auc)
# Out:
# Base loss is 0.17089956808501636 and AUC is 0.7377981587205131

# %%
clf = LGBMClassifier(boosting_type='gbdt',
                     num_leaves=31, max_depth=-1, 
                     learning_rate=0.1, n_estimators=n, 
                     subsample_for_bin=200000, objective=None,
                     class_weight=None, min_split_gain=0.0, 
                     min_child_weight=0.001,
                     min_child_samples=20, subsample=1.0, subsample_freq=1,
                     colsample_bytree=1.0,
                     reg_alpha=0.0, reg_lambda=0.0, random_state=None,
                     n_jobs=-1, silent=False)

# %%
def valid_loss(cols):
    
    print('Running...')
    
    t0 = time.time()
    # select subset of features
    clf.fit(x_train[:, cols], y_train)
    
    y_pred = clf.predict_proba(x_valid[:, cols])[:, 1]
    
    t1 = time.time()
    print(t1 - t0, "s")
    
    return roc_auc_score(y_valid, y_pred)

all_num = int(len(feat_imp) / 100) * 100
print('There are', all_num, 'features waiting to be calculated')

loss = []
break_num = 0

print('Begin to feature selection...')
for i in range(500, all_num, 100):
    loss.append(valid_loss(imp_col_lst[:i]))
    if loss[-1] > base_auc:
        best_num = i
        base_auc = loss[-1]
        break_num += 1
    print('前', i, '个特征的得分为', loss[-1], '而全量得分', base_auc)
    print('\n')
    if break_num == 2:
        
        break
        
print('筛选出来最佳特征个数为', best_num, '这下子训练速度终于可以大大提升了')
# Out:
# There are 11700 features waiting to be calculated
# Begin to feature selection...
# Running...
# [LightGBM] [Info] Number of positive: 337465, number of negative: 6701375
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 3.889155 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1156
# [LightGBM] [Info] Number of data points in the train set: 7038840, number of used features: 500
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.047943 -> initscore=-2.988606
# [LightGBM] [Info] Start training from score -2.988606
# 1739.7665176391602 s
# 前 500 个特征的得分为 0.7358498342854578 而全量得分 0.7377981587205131
#
#
# Running...
# [LightGBM] [Info] Number of positive: 337465, number of negative: 6701375
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 4.479049 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1356
# [LightGBM] [Info] Number of data points in the train set: 7038840, number of used features: 600
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.047943 -> initscore=-2.988606
# [LightGBM] [Info] Start training from score -2.988606
# 2110.466405391693 s
# 前 600 个特征的得分为 0.7378728774543752 而全量得分 0.7378728774543752
#
#
# Running...
# [LightGBM] [Info] Number of positive: 337465, number of negative: 6701375
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 5.568602 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1556
# [LightGBM] [Info] Number of data points in the train set: 7038840, number of used features: 700
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.047943 -> initscore=-2.988606
# [LightGBM] [Info] Start training from score -2.988606
# 2069.7300481796265 s
# 前 700 个特征的得分为 0.7378361367302666 而全量得分 0.7378728774543752
#
#
# Running...
# [LightGBM] [Info] Number of positive: 337465, number of negative: 6701375
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 5.884912 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1756
# [LightGBM] [Info] Number of data points in the train set: 7038840, number of used features: 800
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.047943 -> initscore=-2.988606
# [LightGBM] [Info] Start training from score -2.988606
# 2244.5477397441864 s
# 前 800 个特征的得分为 0.7390469829490792 而全量得分 0.7390469829490792
#
#
# 筛选出来最佳特征个数为 800 这下子训练速度终于可以大大提升了

# %% [markdown]
# ## 保存被选择特征集

# %%
train_part_x = pd.DataFrame()
evals_x = pd.DataFrame()

# 重新读取数据集, 避免保存错了
feat_fname_train = ['train_x_sparse_onehot.npz', 'train_x_sparse_seq_len.npz', 'train_x_sparse_cntv.npz']
feat_fname_valid = ['valid_x_sparse_onehot.npz', 'valid_x_sparse_seq_len.npz', 'valid_x_sparse_cntv.npz']
x_train = pd.DataFrame()
x_valid = pd.DataFrame()
for tr, vl in zip(feat_fname_train, feat_fname_valid):
    train_f = sparse.load_npz(data_prep_dir + tr).tocsr()
    valid_f = sparse.load_npz(data_prep_dir + vl).tocsr()
    
    x_train = sparse.hstack((x_train, train_f)).tocsc()
    x_valid = sparse.hstack((x_valid, valid_f)).tocsc()
    print(tr, train_f.shape)
    print(vl, valid_f.shape)
    
print('x_train:', x_train.shape)
print('x_valid:', x_valid.shape)

print('Loading & merging features completed!')
# Out:
# train_x_sparse_onehot.npz (7038840, 1526)
# valid_x_sparse_onehot.npz (1759974, 1526)
# train_x_sparse_seq_len.npz (7038840, 8)
# valid_x_sparse_seq_len.npz (1759974, 8)
# train_x_sparse_cntv.npz (7038840, 323142)
# valid_x_sparse_cntv.npz (1759974, 323142)
# x_train: (7038840, 324676)
# x_valid: (1759974, 324676)
# Loading & merging features completed!

# %%
col2save = imp_col_lst[: best_num]
x_train2save = x_train[:, col2save]
x_valid2save = x_valid[:, col2save]

sparse.save_npz(data_prep_dir + 'train_x_sparse_selection.npz', x_train2save)
sparse.save_npz(data_prep_dir + 'valid_x_sparse_selection.npz', x_valid2save)

print('train_x_sparse_selection.npz', x_train2save.shape)
print('valid_x_sparse_selection.npz', x_valid2save.shape)
# Out:
# train_x_sparse_selection.npz (7038840, 800)
# valid_x_sparse_selection.npz (1759974, 800)

# %% [markdown]
# # 模型构建

# %%
clf = LGBMClassifier(boosting_type='gbdt', num_leaves=40, max_depth=-1, learning_rate=0.1, 
                n_estimators=10000, subsample_for_bin=200000, objective=None, 
                class_weight=None, min_split_gain=0.0, min_child_weight=0.001, 
                min_child_samples=20, subsample=0.7, subsample_freq=1, 
                colsample_bytree=0.7, 
                reg_alpha=6, reg_lambda=3,
                random_state=2018, n_jobs=-1, silent=False)

# %%
clf.fit(x_train2save, y_train, eval_set = [(x_train2save, y_train), (x_valid2save, y_valid)], 
        eval_names =['train','valid'],
        eval_metric='auc', early_stopping_rounds=50)

auc = int(clf.best_score_['valid']['auc']*1000000)
train_part_x = []
train_part_y = []
# Out:
# [LightGBM] [Info] Number of positive: 337465, number of negative: 6701375
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 6.629200 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1756
# [LightGBM] [Info] Number of data points in the train set: 7038840, number of used features: 800
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.047943 -> initscore=-2.988606
# [LightGBM] [Info] Start training from score -2.988606
# [1]	train's auc: 0.641229	train's binary_logloss: 0.189886	valid's auc: 0.640498	valid's binary_logloss: 0.190082
# Training until validation scores don't improve for 50 rounds
# [2]	train's auc: 0.66071	train's binary_logloss: 0.188155	valid's auc: 0.659761	valid's binary_logloss: 0.18835
# [3]	train's auc: 0.66179	train's binary_logloss: 0.186925	valid's auc: 0.660796	valid's binary_logloss: 0.187111
# [4]	train's auc: 0.66314	train's binary_logloss: 0.185959	valid's auc: 0.661957	valid's binary_logloss: 0.186149
# [5]	train's auc: 0.665551	train's binary_logloss: 0.185129	valid's auc: 0.664519	valid's binary_logloss: 0.185312
# [6]	train's auc: 0.667396	train's binary_logloss: 0.184423	valid's auc: 0.666281	valid's binary_logloss: 0.184611
# [7]	train's auc: 0.669241	train's binary_logloss: 0.183787	valid's auc: 0.668157	valid's binary_logloss: 0.183982
# [8]	train's auc: 0.672604	train's binary_logloss: 0.183234	valid's auc: 0.671668	valid's binary_logloss: 0.183427
# [9]	train's auc: 0.67509	train's binary_logloss: 0.182756	valid's auc: 0.674185	valid's binary_logloss: 0.182954
# [10]	train's auc: 0.676418	train's binary_logloss: 0.18238	valid's auc: 0.675583	valid's binary_logloss: 0.182578
# [11]	train's auc: 0.677667	train's binary_logloss: 0.182034	valid's auc: 0.676937	valid's binary_logloss: 0.182234
# [12]	train's auc: 0.679018	train's binary_logloss: 0.181719	valid's auc: 0.678176	valid's binary_logloss: 0.181929
# [13]	train's auc: 0.680606	train's binary_logloss: 0.181403	valid's auc: 0.679912	valid's binary_logloss: 0.181612
# [14]	train's auc: 0.682369	train's binary_logloss: 0.181137	valid's auc: 0.681491	valid's binary_logloss: 0.181355
# [15]	train's auc: 0.683753	train's binary_logloss: 0.180868	valid's auc: 0.682927	valid's binary_logloss: 0.181087
# [16]	train's auc: 0.684785	train's binary_logloss: 0.180646	valid's auc: 0.684013	valid's binary_logloss: 0.180867
# [17]	train's auc: 0.685568	train's binary_logloss: 0.180417	valid's auc: 0.684795	valid's binary_logloss: 0.180647
# [18]	train's auc: 0.686843	train's binary_logloss: 0.180188	valid's auc: 0.68604	valid's binary_logloss: 0.180421
# [19]	train's auc: 0.688526	train's binary_logloss: 0.179971	valid's auc: 0.687802	valid's binary_logloss: 0.180202
# [20]	train's auc: 0.689141	train's binary_logloss: 0.179796	valid's auc: 0.688405	valid's binary_logloss: 0.180034
# [21]	train's auc: 0.690706	train's binary_logloss: 0.179582	valid's auc: 0.68997	valid's binary_logloss: 0.179823
# [22]	train's auc: 0.691908	train's binary_logloss: 0.179413	valid's auc: 0.691241	valid's binary_logloss: 0.179653
# [23]	train's auc: 0.692849	train's binary_logloss: 0.179268	valid's auc: 0.692168	valid's binary_logloss: 0.179507
# [24]	train's auc: 0.693611	train's binary_logloss: 0.179106	valid's auc: 0.692908	valid's binary_logloss: 0.179343
# [25]	train's auc: 0.694552	train's binary_logloss: 0.178926	valid's auc: 0.693939	valid's binary_logloss: 0.179158
# [26]	train's auc: 0.695076	train's binary_logloss: 0.178799	valid's auc: 0.694445	valid's binary_logloss: 0.179031
# [27]	train's auc: 0.696281	train's binary_logloss: 0.178645	valid's auc: 0.695636	valid's binary_logloss: 0.178879
# [28]	train's auc: 0.696804	train's binary_logloss: 0.178533	valid's auc: 0.696136	valid's binary_logloss: 0.178769
# [29]	train's auc: 0.697471	train's binary_logloss: 0.178401	valid's auc: 0.696789	valid's binary_logloss: 0.178638
# [30]	train's auc: 0.698064	train's binary_logloss: 0.178285	valid's auc: 0.697354	valid's binary_logloss: 0.178522
# [31]	train's auc: 0.698636	train's binary_logloss: 0.178173	valid's auc: 0.697894	valid's binary_logloss: 0.178413
# [32]	train's auc: 0.6991	train's binary_logloss: 0.178085	valid's auc: 0.698336	valid's binary_logloss: 0.178324
# [33]	train's auc: 0.699563	train's binary_logloss: 0.177983	valid's auc: 0.698802	valid's binary_logloss: 0.178226
# [34]	train's auc: 0.700426	train's binary_logloss: 0.177858	valid's auc: 0.699675	valid's binary_logloss: 0.178102
# [35]	train's auc: 0.700958	train's binary_logloss: 0.177762	valid's auc: 0.700254	valid's binary_logloss: 0.178004
# [36]	train's auc: 0.701562	train's binary_logloss: 0.177646	valid's auc: 0.700881	valid's binary_logloss: 0.177888
# [37]	train's auc: 0.702317	train's binary_logloss: 0.177539	valid's auc: 0.701612	valid's binary_logloss: 0.177778
# [38]	train's auc: 0.702754	train's binary_logloss: 0.177462	valid's auc: 0.701993	valid's binary_logloss: 0.177703
# [39]	train's auc: 0.703271	train's binary_logloss: 0.177373	valid's auc: 0.702492	valid's binary_logloss: 0.177614
# [40]	train's auc: 0.704003	train's binary_logloss: 0.177279	valid's auc: 0.703184	valid's binary_logloss: 0.177524
# [41]	train's auc: 0.704559	train's binary_logloss: 0.177186	valid's auc: 0.70366	valid's binary_logloss: 0.177434
# [42]	train's auc: 0.704978	train's binary_logloss: 0.177112	valid's auc: 0.703992	valid's binary_logloss: 0.177366
# [43]	train's auc: 0.705331	train's binary_logloss: 0.177044	valid's auc: 0.704346	valid's binary_logloss: 0.177299
# [44]	train's auc: 0.70573	train's binary_logloss: 0.17698	valid's auc: 0.704762	valid's binary_logloss: 0.177235
# [45]	train's auc: 0.706053	train's binary_logloss: 0.17691	valid's auc: 0.705092	valid's binary_logloss: 0.17717
# [46]	train's auc: 0.706498	train's binary_logloss: 0.176846	valid's auc: 0.705522	valid's binary_logloss: 0.177107
# [47]	train's auc: 0.707108	train's binary_logloss: 0.176751	valid's auc: 0.706205	valid's binary_logloss: 0.177011
# [48]	train's auc: 0.707437	train's binary_logloss: 0.176695	valid's auc: 0.706543	valid's binary_logloss: 0.176957
# [49]	train's auc: 0.70776	train's binary_logloss: 0.176619	valid's auc: 0.706842	valid's binary_logloss: 0.176882
# [50]	train's auc: 0.708216	train's binary_logloss: 0.176549	valid's auc: 0.707331	valid's binary_logloss: 0.176811
# [51]	train's auc: 0.708511	train's binary_logloss: 0.176479	valid's auc: 0.707586	valid's binary_logloss: 0.176744
# [52]	train's auc: 0.709048	train's binary_logloss: 0.176394	valid's auc: 0.708119	valid's binary_logloss: 0.176661
# [53]	train's auc: 0.709334	train's binary_logloss: 0.176325	valid's auc: 0.708419	valid's binary_logloss: 0.17659
# [54]	train's auc: 0.709635	train's binary_logloss: 0.176266	valid's auc: 0.708686	valid's binary_logloss: 0.176532
# [55]	train's auc: 0.709954	train's binary_logloss: 0.176208	valid's auc: 0.709023	valid's binary_logloss: 0.176473
# [56]	train's auc: 0.71023	train's binary_logloss: 0.176145	valid's auc: 0.709251	valid's binary_logloss: 0.176416
# [57]	train's auc: 0.710599	train's binary_logloss: 0.17608	valid's auc: 0.709659	valid's binary_logloss: 0.176351
# [58]	train's auc: 0.710973	train's binary_logloss: 0.176028	valid's auc: 0.709985	valid's binary_logloss: 0.176304
# [59]	train's auc: 0.711344	train's binary_logloss: 0.175975	valid's auc: 0.710342	valid's binary_logloss: 0.176253
# [60]	train's auc: 0.711646	train's binary_logloss: 0.175923	valid's auc: 0.710631	valid's binary_logloss: 0.176204
# [61]	train's auc: 0.711894	train's binary_logloss: 0.175865	valid's auc: 0.710879	valid's binary_logloss: 0.176146
# [62]	train's auc: 0.712219	train's binary_logloss: 0.175821	valid's auc: 0.711186	valid's binary_logloss: 0.176104
# [63]	train's auc: 0.712447	train's binary_logloss: 0.175765	valid's auc: 0.711412	valid's binary_logloss: 0.176052
# [64]	train's auc: 0.712623	train's binary_logloss: 0.175723	valid's auc: 0.71155	valid's binary_logloss: 0.176015
# [65]	train's auc: 0.712923	train's binary_logloss: 0.175676	valid's auc: 0.711803	valid's binary_logloss: 0.175971
# [66]	train's auc: 0.713404	train's binary_logloss: 0.175626	valid's auc: 0.712236	valid's binary_logloss: 0.175924
# [67]	train's auc: 0.71363	train's binary_logloss: 0.175573	valid's auc: 0.712434	valid's binary_logloss: 0.175876
# [68]	train's auc: 0.714034	train's binary_logloss: 0.175509	valid's auc: 0.712814	valid's binary_logloss: 0.175812
# [69]	train's auc: 0.714337	train's binary_logloss: 0.17546	valid's auc: 0.71313	valid's binary_logloss: 0.175761
# [70]	train's auc: 0.714535	train's binary_logloss: 0.175419	valid's auc: 0.713293	valid's binary_logloss: 0.175723
# [71]	train's auc: 0.714837	train's binary_logloss: 0.175371	valid's auc: 0.713602	valid's binary_logloss: 0.175674
# [72]	train's auc: 0.715156	train's binary_logloss: 0.175324	valid's auc: 0.713886	valid's binary_logloss: 0.175632
# [73]	train's auc: 0.715352	train's binary_logloss: 0.175281	valid's auc: 0.714078	valid's binary_logloss: 0.175592
# [74]	train's auc: 0.715577	train's binary_logloss: 0.175242	valid's auc: 0.714337	valid's binary_logloss: 0.17555
# [75]	train's auc: 0.715742	train's binary_logloss: 0.175195	valid's auc: 0.714506	valid's binary_logloss: 0.175504
# [76]	train's auc: 0.715926	train's binary_logloss: 0.175155	valid's auc: 0.714661	valid's binary_logloss: 0.175467
# [77]	train's auc: 0.716123	train's binary_logloss: 0.175117	valid's auc: 0.714841	valid's binary_logloss: 0.17543
# [78]	train's auc: 0.716307	train's binary_logloss: 0.175079	valid's auc: 0.715003	valid's binary_logloss: 0.175396
# [79]	train's auc: 0.716545	train's binary_logloss: 0.175042	valid's auc: 0.715212	valid's binary_logloss: 0.175363
# [80]	train's auc: 0.716758	train's binary_logloss: 0.175	valid's auc: 0.715409	valid's binary_logloss: 0.175327
# [81]	train's auc: 0.716959	train's binary_logloss: 0.174962	valid's auc: 0.715603	valid's binary_logloss: 0.175289
# [82]	train's auc: 0.717218	train's binary_logloss: 0.174924	valid's auc: 0.715844	valid's binary_logloss: 0.175254
# [83]	train's auc: 0.717494	train's binary_logloss: 0.174869	valid's auc: 0.716077	valid's binary_logloss: 0.175202
# [84]	train's auc: 0.717664	train's binary_logloss: 0.174839	valid's auc: 0.716216	valid's binary_logloss: 0.175174
# [85]	train's auc: 0.717817	train's binary_logloss: 0.174808	valid's auc: 0.716356	valid's binary_logloss: 0.175147
# [86]	train's auc: 0.718026	train's binary_logloss: 0.17477	valid's auc: 0.716559	valid's binary_logloss: 0.17511
# [87]	train's auc: 0.718227	train's binary_logloss: 0.174731	valid's auc: 0.716738	valid's binary_logloss: 0.175075
# [88]	train's auc: 0.718409	train's binary_logloss: 0.174704	valid's auc: 0.716893	valid's binary_logloss: 0.175049
# [89]	train's auc: 0.718599	train's binary_logloss: 0.174657	valid's auc: 0.717071	valid's binary_logloss: 0.175004
# [90]	train's auc: 0.718789	train's binary_logloss: 0.174622	valid's auc: 0.71724	valid's binary_logloss: 0.174972
# [91]	train's auc: 0.718984	train's binary_logloss: 0.174581	valid's auc: 0.717413	valid's binary_logloss: 0.174936
# [92]	train's auc: 0.719257	train's binary_logloss: 0.174541	valid's auc: 0.717661	valid's binary_logloss: 0.174898
# [93]	train's auc: 0.719462	train's binary_logloss: 0.174507	valid's auc: 0.717841	valid's binary_logloss: 0.174868
# [94]	train's auc: 0.719595	train's binary_logloss: 0.174475	valid's auc: 0.717972	valid's binary_logloss: 0.174838
# [95]	train's auc: 0.719745	train's binary_logloss: 0.17445	valid's auc: 0.718095	valid's binary_logloss: 0.174816
# [96]	train's auc: 0.719949	train's binary_logloss: 0.174419	valid's auc: 0.718311	valid's binary_logloss: 0.174785
# [97]	train's auc: 0.720186	train's binary_logloss: 0.174382	valid's auc: 0.718508	valid's binary_logloss: 0.174752
# [98]	train's auc: 0.72037	train's binary_logloss: 0.174355	valid's auc: 0.718709	valid's binary_logloss: 0.174727
# [99]	train's auc: 0.720495	train's binary_logloss: 0.174333	valid's auc: 0.718813	valid's binary_logloss: 0.174708
# [100]	train's auc: 0.72063	train's binary_logloss: 0.174306	valid's auc: 0.718936	valid's binary_logloss: 0.174684
# [101]	train's auc: 0.720833	train's binary_logloss: 0.174272	valid's auc: 0.719091	valid's binary_logloss: 0.174654
# [102]	train's auc: 0.721018	train's binary_logloss: 0.174242	valid's auc: 0.719268	valid's binary_logloss: 0.174623
# [103]	train's auc: 0.721165	train's binary_logloss: 0.174214	valid's auc: 0.719405	valid's binary_logloss: 0.1746
# [104]	train's auc: 0.721282	train's binary_logloss: 0.174187	valid's auc: 0.71951	valid's binary_logloss: 0.174575
# [105]	train's auc: 0.721428	train's binary_logloss: 0.174156	valid's auc: 0.719626	valid's binary_logloss: 0.17455
# [106]	train's auc: 0.721542	train's binary_logloss: 0.174133	valid's auc: 0.719743	valid's binary_logloss: 0.174526
# [107]	train's auc: 0.72172	train's binary_logloss: 0.174108	valid's auc: 0.719909	valid's binary_logloss: 0.174504
# [108]	train's auc: 0.721903	train's binary_logloss: 0.174075	valid's auc: 0.720068	valid's binary_logloss: 0.174472
# [109]	train's auc: 0.722029	train's binary_logloss: 0.174047	valid's auc: 0.72018	valid's binary_logloss: 0.174447
# [110]	train's auc: 0.722221	train's binary_logloss: 0.174022	valid's auc: 0.720352	valid's binary_logloss: 0.174427
# [111]	train's auc: 0.722337	train's binary_logloss: 0.173999	valid's auc: 0.720456	valid's binary_logloss: 0.174404
# [112]	train's auc: 0.722494	train's binary_logloss: 0.173973	valid's auc: 0.720597	valid's binary_logloss: 0.17438
# [113]	train's auc: 0.722592	train's binary_logloss: 0.173954	valid's auc: 0.720698	valid's binary_logloss: 0.174362
# [114]	train's auc: 0.722767	train's binary_logloss: 0.173922	valid's auc: 0.720849	valid's binary_logloss: 0.174335
# [115]	train's auc: 0.722832	train's binary_logloss: 0.173905	valid's auc: 0.720892	valid's binary_logloss: 0.174321
# [116]	train's auc: 0.722984	train's binary_logloss: 0.173879	valid's auc: 0.721036	valid's binary_logloss: 0.174297
# [117]	train's auc: 0.723119	train's binary_logloss: 0.173857	valid's auc: 0.721167	valid's binary_logloss: 0.174276
# [118]	train's auc: 0.723427	train's binary_logloss: 0.173816	valid's auc: 0.721451	valid's binary_logloss: 0.174239
# [119]	train's auc: 0.723643	train's binary_logloss: 0.173785	valid's auc: 0.721674	valid's binary_logloss: 0.174208
# [120]	train's auc: 0.723756	train's binary_logloss: 0.173767	valid's auc: 0.721782	valid's binary_logloss: 0.17419
# [121]	train's auc: 0.723954	train's binary_logloss: 0.173737	valid's auc: 0.721948	valid's binary_logloss: 0.174162
# [122]	train's auc: 0.724075	train's binary_logloss: 0.173715	valid's auc: 0.722057	valid's binary_logloss: 0.174141
# [123]	train's auc: 0.7242	train's binary_logloss: 0.173692	valid's auc: 0.722164	valid's binary_logloss: 0.174121
# [124]	train's auc: 0.724288	train's binary_logloss: 0.17367	valid's auc: 0.722249	valid's binary_logloss: 0.174101
# [125]	train's auc: 0.72443	train's binary_logloss: 0.17364	valid's auc: 0.722416	valid's binary_logloss: 0.174071
# [126]	train's auc: 0.724499	train's binary_logloss: 0.173623	valid's auc: 0.722461	valid's binary_logloss: 0.174055
# [127]	train's auc: 0.724638	train's binary_logloss: 0.173603	valid's auc: 0.722582	valid's binary_logloss: 0.174039
# [128]	train's auc: 0.72477	train's binary_logloss: 0.173584	valid's auc: 0.722683	valid's binary_logloss: 0.174022
# [129]	train's auc: 0.724879	train's binary_logloss: 0.173566	valid's auc: 0.722771	valid's binary_logloss: 0.174006
# [130]	train's auc: 0.725015	train's binary_logloss: 0.173546	valid's auc: 0.722897	valid's binary_logloss: 0.173988
# [131]	train's auc: 0.725115	train's binary_logloss: 0.173526	valid's auc: 0.722987	valid's binary_logloss: 0.17397
# [132]	train's auc: 0.725225	train's binary_logloss: 0.173508	valid's auc: 0.723077	valid's binary_logloss: 0.173954
# [133]	train's auc: 0.725313	train's binary_logloss: 0.17349	valid's auc: 0.723127	valid's binary_logloss: 0.17394
# [134]	train's auc: 0.725435	train's binary_logloss: 0.173472	valid's auc: 0.72323	valid's binary_logloss: 0.173925
# [135]	train's auc: 0.725545	train's binary_logloss: 0.17345	valid's auc: 0.723321	valid's binary_logloss: 0.173907
# [136]	train's auc: 0.725592	train's binary_logloss: 0.173434	valid's auc: 0.723355	valid's binary_logloss: 0.173893
# [137]	train's auc: 0.725768	train's binary_logloss: 0.173409	valid's auc: 0.723507	valid's binary_logloss: 0.173871
# [138]	train's auc: 0.725874	train's binary_logloss: 0.173392	valid's auc: 0.723602	valid's binary_logloss: 0.173855
# [139]	train's auc: 0.726002	train's binary_logloss: 0.173369	valid's auc: 0.723733	valid's binary_logloss: 0.173834
# [140]	train's auc: 0.726183	train's binary_logloss: 0.173346	valid's auc: 0.723904	valid's binary_logloss: 0.173811
# [141]	train's auc: 0.726313	train's binary_logloss: 0.173326	valid's auc: 0.724011	valid's binary_logloss: 0.173795
# [142]	train's auc: 0.726398	train's binary_logloss: 0.173305	valid's auc: 0.724082	valid's binary_logloss: 0.173777
# [143]	train's auc: 0.726488	train's binary_logloss: 0.173289	valid's auc: 0.724174	valid's binary_logloss: 0.173762
# [144]	train's auc: 0.726614	train's binary_logloss: 0.173271	valid's auc: 0.724279	valid's binary_logloss: 0.173747
# [145]	train's auc: 0.726688	train's binary_logloss: 0.173255	valid's auc: 0.724336	valid's binary_logloss: 0.173734
# [146]	train's auc: 0.72681	train's binary_logloss: 0.173234	valid's auc: 0.724478	valid's binary_logloss: 0.173713
# [147]	train's auc: 0.726885	train's binary_logloss: 0.173218	valid's auc: 0.724544	valid's binary_logloss: 0.173699
# [148]	train's auc: 0.726997	train's binary_logloss: 0.173201	valid's auc: 0.724627	valid's binary_logloss: 0.173685
# [149]	train's auc: 0.727067	train's binary_logloss: 0.173186	valid's auc: 0.724692	valid's binary_logloss: 0.173673
# [150]	train's auc: 0.727152	train's binary_logloss: 0.173167	valid's auc: 0.724771	valid's binary_logloss: 0.173657
# [151]	train's auc: 0.727315	train's binary_logloss: 0.173134	valid's auc: 0.724925	valid's binary_logloss: 0.173625
# [152]	train's auc: 0.727391	train's binary_logloss: 0.17312	valid's auc: 0.724994	valid's binary_logloss: 0.173613
# [153]	train's auc: 0.727463	train's binary_logloss: 0.173106	valid's auc: 0.725048	valid's binary_logloss: 0.173602
# [154]	train's auc: 0.727595	train's binary_logloss: 0.173081	valid's auc: 0.725188	valid's binary_logloss: 0.173578
# [155]	train's auc: 0.727682	train's binary_logloss: 0.173066	valid's auc: 0.725269	valid's binary_logloss: 0.173565
# [156]	train's auc: 0.727792	train's binary_logloss: 0.173048	valid's auc: 0.725364	valid's binary_logloss: 0.173549
# [157]	train's auc: 0.727929	train's binary_logloss: 0.173027	valid's auc: 0.725494	valid's binary_logloss: 0.17353
# [158]	train's auc: 0.727997	train's binary_logloss: 0.17301	valid's auc: 0.725566	valid's binary_logloss: 0.173516
# [159]	train's auc: 0.728078	train's binary_logloss: 0.172995	valid's auc: 0.725634	valid's binary_logloss: 0.173503
# [160]	train's auc: 0.728155	train's binary_logloss: 0.172981	valid's auc: 0.725684	valid's binary_logloss: 0.173491
# [161]	train's auc: 0.728233	train's binary_logloss: 0.172966	valid's auc: 0.725738	valid's binary_logloss: 0.173479
# [162]	train's auc: 0.728321	train's binary_logloss: 0.172951	valid's auc: 0.725804	valid's binary_logloss: 0.173466
# [163]	train's auc: 0.728419	train's binary_logloss: 0.172936	valid's auc: 0.725896	valid's binary_logloss: 0.173453
# [164]	train's auc: 0.728525	train's binary_logloss: 0.172917	valid's auc: 0.725976	valid's binary_logloss: 0.173438
# [165]	train's auc: 0.72859	train's binary_logloss: 0.172902	valid's auc: 0.726022	valid's binary_logloss: 0.173427
# [166]	train's auc: 0.728667	train's binary_logloss: 0.172889	valid's auc: 0.726078	valid's binary_logloss: 0.173417
# [167]	train's auc: 0.728754	train's binary_logloss: 0.172869	valid's auc: 0.726144	valid's binary_logloss: 0.173401
# [168]	train's auc: 0.728846	train's binary_logloss: 0.172855	valid's auc: 0.726242	valid's binary_logloss: 0.173387
# [169]	train's auc: 0.728923	train's binary_logloss: 0.172838	valid's auc: 0.726317	valid's binary_logloss: 0.173371
# [170]	train's auc: 0.728981	train's binary_logloss: 0.172825	valid's auc: 0.726356	valid's binary_logloss: 0.17336
# [171]	train's auc: 0.729081	train's binary_logloss: 0.172807	valid's auc: 0.726427	valid's binary_logloss: 0.173346
# [172]	train's auc: 0.729206	train's binary_logloss: 0.172785	valid's auc: 0.726536	valid's binary_logloss: 0.173327
# [173]	train's auc: 0.729273	train's binary_logloss: 0.172772	valid's auc: 0.726583	valid's binary_logloss: 0.173316
# [174]	train's auc: 0.729362	train's binary_logloss: 0.172758	valid's auc: 0.726663	valid's binary_logloss: 0.173304
# [175]	train's auc: 0.729458	train's binary_logloss: 0.172742	valid's auc: 0.726748	valid's binary_logloss: 0.173291
# [176]	train's auc: 0.729547	train's binary_logloss: 0.172725	valid's auc: 0.72682	valid's binary_logloss: 0.173278
# [177]	train's auc: 0.729609	train's binary_logloss: 0.172713	valid's auc: 0.726871	valid's binary_logloss: 0.173268
# [178]	train's auc: 0.729671	train's binary_logloss: 0.172701	valid's auc: 0.726933	valid's binary_logloss: 0.173256
# [179]	train's auc: 0.729752	train's binary_logloss: 0.172689	valid's auc: 0.726998	valid's binary_logloss: 0.173247
# [180]	train's auc: 0.729907	train's binary_logloss: 0.172667	valid's auc: 0.727152	valid's binary_logloss: 0.173226
# [181]	train's auc: 0.729973	train's binary_logloss: 0.172655	valid's auc: 0.727202	valid's binary_logloss: 0.173217
# [182]	train's auc: 0.730043	train's binary_logloss: 0.172641	valid's auc: 0.727255	valid's binary_logloss: 0.173204
# [183]	train's auc: 0.730085	train's binary_logloss: 0.172629	valid's auc: 0.727301	valid's binary_logloss: 0.173194
# [184]	train's auc: 0.730159	train's binary_logloss: 0.17262	valid's auc: 0.727357	valid's binary_logloss: 0.173187
# [185]	train's auc: 0.730244	train's binary_logloss: 0.172603	valid's auc: 0.727437	valid's binary_logloss: 0.173173
# [186]	train's auc: 0.730298	train's binary_logloss: 0.17259	valid's auc: 0.727471	valid's binary_logloss: 0.173163
# [187]	train's auc: 0.730358	train's binary_logloss: 0.172578	valid's auc: 0.727518	valid's binary_logloss: 0.173154
# [188]	train's auc: 0.730422	train's binary_logloss: 0.172566	valid's auc: 0.727566	valid's binary_logloss: 0.173146
# [189]	train's auc: 0.730536	train's binary_logloss: 0.172551	valid's auc: 0.727687	valid's binary_logloss: 0.173131
# [190]	train's auc: 0.730602	train's binary_logloss: 0.172541	valid's auc: 0.72774	valid's binary_logloss: 0.173123
# [191]	train's auc: 0.730678	train's binary_logloss: 0.172527	valid's auc: 0.727809	valid's binary_logloss: 0.17311
# [192]	train's auc: 0.730793	train's binary_logloss: 0.172509	valid's auc: 0.727904	valid's binary_logloss: 0.173096
# [193]	train's auc: 0.730856	train's binary_logloss: 0.172498	valid's auc: 0.727949	valid's binary_logloss: 0.173086
# [194]	train's auc: 0.730952	train's binary_logloss: 0.172483	valid's auc: 0.728029	valid's binary_logloss: 0.173075
# [195]	train's auc: 0.731038	train's binary_logloss: 0.17247	valid's auc: 0.728107	valid's binary_logloss: 0.173063
# [196]	train's auc: 0.731103	train's binary_logloss: 0.172459	valid's auc: 0.728142	valid's binary_logloss: 0.173055
# [197]	train's auc: 0.731225	train's binary_logloss: 0.172442	valid's auc: 0.728271	valid's binary_logloss: 0.173038
# [198]	train's auc: 0.731289	train's binary_logloss: 0.17243	valid's auc: 0.72833	valid's binary_logloss: 0.173028
# [199]	train's auc: 0.731349	train's binary_logloss: 0.172419	valid's auc: 0.728367	valid's binary_logloss: 0.173021
# [200]	train's auc: 0.731399	train's binary_logloss: 0.172411	valid's auc: 0.728389	valid's binary_logloss: 0.173016
# [201]	train's auc: 0.731481	train's binary_logloss: 0.172398	valid's auc: 0.728478	valid's binary_logloss: 0.173003
# [202]	train's auc: 0.73153	train's binary_logloss: 0.172385	valid's auc: 0.728515	valid's binary_logloss: 0.172994
# [203]	train's auc: 0.731584	train's binary_logloss: 0.172375	valid's auc: 0.728557	valid's binary_logloss: 0.172987
# [204]	train's auc: 0.731659	train's binary_logloss: 0.172362	valid's auc: 0.728614	valid's binary_logloss: 0.172977
# [205]	train's auc: 0.731715	train's binary_logloss: 0.172351	valid's auc: 0.728655	valid's binary_logloss: 0.172969
# [206]	train's auc: 0.731802	train's binary_logloss: 0.172339	valid's auc: 0.728715	valid's binary_logloss: 0.172961
# [207]	train's auc: 0.731857	train's binary_logloss: 0.172329	valid's auc: 0.728761	valid's binary_logloss: 0.172953
# [208]	train's auc: 0.731901	train's binary_logloss: 0.172321	valid's auc: 0.728795	valid's binary_logloss: 0.172946
# [209]	train's auc: 0.732027	train's binary_logloss: 0.172304	valid's auc: 0.728905	valid's binary_logloss: 0.172931
# [210]	train's auc: 0.732106	train's binary_logloss: 0.172293	valid's auc: 0.728957	valid's binary_logloss: 0.172923
# [211]	train's auc: 0.732173	train's binary_logloss: 0.172281	valid's auc: 0.729009	valid's binary_logloss: 0.172913
# [212]	train's auc: 0.73234	train's binary_logloss: 0.172257	valid's auc: 0.72915	valid's binary_logloss: 0.172892
# [213]	train's auc: 0.732401	train's binary_logloss: 0.172245	valid's auc: 0.729218	valid's binary_logloss: 0.172881
# [214]	train's auc: 0.732513	train's binary_logloss: 0.17223	valid's auc: 0.729312	valid's binary_logloss: 0.172869
# [215]	train's auc: 0.732667	train's binary_logloss: 0.172212	valid's auc: 0.729456	valid's binary_logloss: 0.172853
# [216]	train's auc: 0.732763	train's binary_logloss: 0.172197	valid's auc: 0.729528	valid's binary_logloss: 0.172841
# [217]	train's auc: 0.732819	train's binary_logloss: 0.172187	valid's auc: 0.729564	valid's binary_logloss: 0.172834
# [218]	train's auc: 0.732921	train's binary_logloss: 0.172172	valid's auc: 0.729643	valid's binary_logloss: 0.172821
# [219]	train's auc: 0.732985	train's binary_logloss: 0.172158	valid's auc: 0.729701	valid's binary_logloss: 0.172808
# [220]	train's auc: 0.733061	train's binary_logloss: 0.172147	valid's auc: 0.729762	valid's binary_logloss: 0.172799
# [221]	train's auc: 0.733105	train's binary_logloss: 0.172138	valid's auc: 0.7298	valid's binary_logloss: 0.172793
# [222]	train's auc: 0.733186	train's binary_logloss: 0.172124	valid's auc: 0.729873	valid's binary_logloss: 0.17278
# [223]	train's auc: 0.733246	train's binary_logloss: 0.172113	valid's auc: 0.729918	valid's binary_logloss: 0.172772
# [224]	train's auc: 0.733283	train's binary_logloss: 0.172103	valid's auc: 0.729958	valid's binary_logloss: 0.172763
# [225]	train's auc: 0.733358	train's binary_logloss: 0.17209	valid's auc: 0.73001	valid's binary_logloss: 0.172752
# [226]	train's auc: 0.733397	train's binary_logloss: 0.17208	valid's auc: 0.730035	valid's binary_logloss: 0.172746
# [227]	train's auc: 0.733456	train's binary_logloss: 0.172065	valid's auc: 0.730093	valid's binary_logloss: 0.172732
# [228]	train's auc: 0.733499	train's binary_logloss: 0.172054	valid's auc: 0.730122	valid's binary_logloss: 0.172723
# [229]	train's auc: 0.733555	train's binary_logloss: 0.172042	valid's auc: 0.730161	valid's binary_logloss: 0.172714
# [230]	train's auc: 0.733622	train's binary_logloss: 0.172031	valid's auc: 0.730207	valid's binary_logloss: 0.172707
# [231]	train's auc: 0.73368	train's binary_logloss: 0.172023	valid's auc: 0.730238	valid's binary_logloss: 0.172702
# [232]	train's auc: 0.733729	train's binary_logloss: 0.172014	valid's auc: 0.730268	valid's binary_logloss: 0.172696
# [233]	train's auc: 0.733787	train's binary_logloss: 0.172004	valid's auc: 0.730309	valid's binary_logloss: 0.172688
# [234]	train's auc: 0.733846	train's binary_logloss: 0.171994	valid's auc: 0.730357	valid's binary_logloss: 0.172681
# [235]	train's auc: 0.733911	train's binary_logloss: 0.171985	valid's auc: 0.730413	valid's binary_logloss: 0.172674
# [236]	train's auc: 0.733976	train's binary_logloss: 0.171976	valid's auc: 0.730466	valid's binary_logloss: 0.172667
# [237]	train's auc: 0.734058	train's binary_logloss: 0.171963	valid's auc: 0.730536	valid's binary_logloss: 0.172657
# [238]	train's auc: 0.734121	train's binary_logloss: 0.171952	valid's auc: 0.730593	valid's binary_logloss: 0.172647
# [239]	train's auc: 0.734179	train's binary_logloss: 0.171943	valid's auc: 0.730628	valid's binary_logloss: 0.172641
# [240]	train's auc: 0.73435	train's binary_logloss: 0.17192	valid's auc: 0.730798	valid's binary_logloss: 0.172619
# [241]	train's auc: 0.734401	train's binary_logloss: 0.171911	valid's auc: 0.730838	valid's binary_logloss: 0.172612
# [242]	train's auc: 0.734463	train's binary_logloss: 0.171901	valid's auc: 0.730883	valid's binary_logloss: 0.172605
# [243]	train's auc: 0.734506	train's binary_logloss: 0.171892	valid's auc: 0.730919	valid's binary_logloss: 0.172598
# [244]	train's auc: 0.734542	train's binary_logloss: 0.171883	valid's auc: 0.730942	valid's binary_logloss: 0.172593
# [245]	train's auc: 0.734586	train's binary_logloss: 0.171876	valid's auc: 0.730979	valid's binary_logloss: 0.172587
# [246]	train's auc: 0.734635	train's binary_logloss: 0.171866	valid's auc: 0.731016	valid's binary_logloss: 0.17258
# [247]	train's auc: 0.734682	train's binary_logloss: 0.171855	valid's auc: 0.731052	valid's binary_logloss: 0.17257
# [248]	train's auc: 0.734747	train's binary_logloss: 0.171845	valid's auc: 0.731101	valid's binary_logloss: 0.172562
# [249]	train's auc: 0.734804	train's binary_logloss: 0.171836	valid's auc: 0.731142	valid's binary_logloss: 0.172554
# [250]	train's auc: 0.734837	train's binary_logloss: 0.171828	valid's auc: 0.731164	valid's binary_logloss: 0.172549
# [251]	train's auc: 0.734886	train's binary_logloss: 0.171819	valid's auc: 0.731197	valid's binary_logloss: 0.172543
# [252]	train's auc: 0.73498	train's binary_logloss: 0.171803	valid's auc: 0.731265	valid's binary_logloss: 0.172529
# [253]	train's auc: 0.735047	train's binary_logloss: 0.171792	valid's auc: 0.731326	valid's binary_logloss: 0.172519
# [254]	train's auc: 0.735103	train's binary_logloss: 0.171781	valid's auc: 0.731372	valid's binary_logloss: 0.172511
# [255]	train's auc: 0.735149	train's binary_logloss: 0.171773	valid's auc: 0.731398	valid's binary_logloss: 0.172506
# [256]	train's auc: 0.735188	train's binary_logloss: 0.171766	valid's auc: 0.731412	valid's binary_logloss: 0.172503
# [257]	train's auc: 0.735252	train's binary_logloss: 0.171756	valid's auc: 0.731451	valid's binary_logloss: 0.172496
# [258]	train's auc: 0.735294	train's binary_logloss: 0.171749	valid's auc: 0.731474	valid's binary_logloss: 0.172493
# [259]	train's auc: 0.735351	train's binary_logloss: 0.171739	valid's auc: 0.731517	valid's binary_logloss: 0.172486
# [260]	train's auc: 0.735412	train's binary_logloss: 0.171729	valid's auc: 0.731549	valid's binary_logloss: 0.172479
# [261]	train's auc: 0.735459	train's binary_logloss: 0.171721	valid's auc: 0.731581	valid's binary_logloss: 0.172474
# [262]	train's auc: 0.735507	train's binary_logloss: 0.171713	valid's auc: 0.731609	valid's binary_logloss: 0.172469
# [263]	train's auc: 0.735552	train's binary_logloss: 0.171705	valid's auc: 0.73164	valid's binary_logloss: 0.172464
# [264]	train's auc: 0.7356	train's binary_logloss: 0.171698	valid's auc: 0.731672	valid's binary_logloss: 0.17246
# [265]	train's auc: 0.735638	train's binary_logloss: 0.17169	valid's auc: 0.731704	valid's binary_logloss: 0.172454
# [266]	train's auc: 0.735689	train's binary_logloss: 0.171682	valid's auc: 0.731733	valid's binary_logloss: 0.172448
# [267]	train's auc: 0.735724	train's binary_logloss: 0.17167	valid's auc: 0.731758	valid's binary_logloss: 0.172438
# [268]	train's auc: 0.735845	train's binary_logloss: 0.171653	valid's auc: 0.731875	valid's binary_logloss: 0.172421
# [269]	train's auc: 0.735911	train's binary_logloss: 0.171645	valid's auc: 0.731903	valid's binary_logloss: 0.172417
# [270]	train's auc: 0.735956	train's binary_logloss: 0.171637	valid's auc: 0.731919	valid's binary_logloss: 0.172413
# [271]	train's auc: 0.736064	train's binary_logloss: 0.171622	valid's auc: 0.732018	valid's binary_logloss: 0.172399
# [272]	train's auc: 0.736126	train's binary_logloss: 0.171613	valid's auc: 0.732056	valid's binary_logloss: 0.172392
# [273]	train's auc: 0.736183	train's binary_logloss: 0.171603	valid's auc: 0.732092	valid's binary_logloss: 0.172386
# [274]	train's auc: 0.736215	train's binary_logloss: 0.171598	valid's auc: 0.732102	valid's binary_logloss: 0.172384
# [275]	train's auc: 0.736284	train's binary_logloss: 0.171586	valid's auc: 0.732149	valid's binary_logloss: 0.172375
# [276]	train's auc: 0.736323	train's binary_logloss: 0.171577	valid's auc: 0.732179	valid's binary_logloss: 0.172368
# [277]	train's auc: 0.736367	train's binary_logloss: 0.17157	valid's auc: 0.732211	valid's binary_logloss: 0.172363
# [278]	train's auc: 0.736438	train's binary_logloss: 0.171557	valid's auc: 0.732265	valid's binary_logloss: 0.172353
# [279]	train's auc: 0.736481	train's binary_logloss: 0.171549	valid's auc: 0.732296	valid's binary_logloss: 0.172347
# [280]	train's auc: 0.736578	train's binary_logloss: 0.171536	valid's auc: 0.732366	valid's binary_logloss: 0.172337
# [281]	train's auc: 0.736622	train's binary_logloss: 0.171529	valid's auc: 0.732387	valid's binary_logloss: 0.172334
# [282]	train's auc: 0.736672	train's binary_logloss: 0.171521	valid's auc: 0.732414	valid's binary_logloss: 0.172329
# [283]	train's auc: 0.736717	train's binary_logloss: 0.171514	valid's auc: 0.73244	valid's binary_logloss: 0.172323
# [284]	train's auc: 0.736756	train's binary_logloss: 0.171507	valid's auc: 0.732462	valid's binary_logloss: 0.17232
# [285]	train's auc: 0.736878	train's binary_logloss: 0.171491	valid's auc: 0.73257	valid's binary_logloss: 0.172306
# [286]	train's auc: 0.736942	train's binary_logloss: 0.171482	valid's auc: 0.732607	valid's binary_logloss: 0.172298
# [287]	train's auc: 0.736989	train's binary_logloss: 0.171473	valid's auc: 0.732643	valid's binary_logloss: 0.172292
# [288]	train's auc: 0.737044	train's binary_logloss: 0.171466	valid's auc: 0.732669	valid's binary_logloss: 0.172288
# [289]	train's auc: 0.737085	train's binary_logloss: 0.171459	valid's auc: 0.732712	valid's binary_logloss: 0.172282
# [290]	train's auc: 0.737121	train's binary_logloss: 0.171452	valid's auc: 0.732742	valid's binary_logloss: 0.172277
# [291]	train's auc: 0.737168	train's binary_logloss: 0.171443	valid's auc: 0.732763	valid's binary_logloss: 0.172271
# [292]	train's auc: 0.737214	train's binary_logloss: 0.171435	valid's auc: 0.732793	valid's binary_logloss: 0.172266
# [293]	train's auc: 0.73725	train's binary_logloss: 0.171427	valid's auc: 0.732813	valid's binary_logloss: 0.172262
# [294]	train's auc: 0.73728	train's binary_logloss: 0.17142	valid's auc: 0.732829	valid's binary_logloss: 0.172258
# [295]	train's auc: 0.737333	train's binary_logloss: 0.17141	valid's auc: 0.732862	valid's binary_logloss: 0.172251
# [296]	train's auc: 0.737375	train's binary_logloss: 0.171403	valid's auc: 0.732885	valid's binary_logloss: 0.172247
# [297]	train's auc: 0.737457	train's binary_logloss: 0.17139	valid's auc: 0.732947	valid's binary_logloss: 0.172237
# [298]	train's auc: 0.737502	train's binary_logloss: 0.171384	valid's auc: 0.732968	valid's binary_logloss: 0.172235
# [299]	train's auc: 0.73755	train's binary_logloss: 0.171376	valid's auc: 0.732997	valid's binary_logloss: 0.172229
# [300]	train's auc: 0.737612	train's binary_logloss: 0.171366	valid's auc: 0.733036	valid's binary_logloss: 0.17222
# [301]	train's auc: 0.737655	train's binary_logloss: 0.171359	valid's auc: 0.733061	valid's binary_logloss: 0.172217
# [302]	train's auc: 0.737693	train's binary_logloss: 0.171352	valid's auc: 0.733095	valid's binary_logloss: 0.172211
# [303]	train's auc: 0.737731	train's binary_logloss: 0.171345	valid's auc: 0.733111	valid's binary_logloss: 0.172208
# [304]	train's auc: 0.737802	train's binary_logloss: 0.171336	valid's auc: 0.733171	valid's binary_logloss: 0.1722
# [305]	train's auc: 0.73786	train's binary_logloss: 0.171326	valid's auc: 0.733206	valid's binary_logloss: 0.172194
# [306]	train's auc: 0.737922	train's binary_logloss: 0.171316	valid's auc: 0.733249	valid's binary_logloss: 0.172187
# [307]	train's auc: 0.738015	train's binary_logloss: 0.171303	valid's auc: 0.733325	valid's binary_logloss: 0.172176
# [308]	train's auc: 0.738041	train's binary_logloss: 0.171298	valid's auc: 0.733336	valid's binary_logloss: 0.172174
# [309]	train's auc: 0.738109	train's binary_logloss: 0.171288	valid's auc: 0.733388	valid's binary_logloss: 0.172166
# [310]	train's auc: 0.738139	train's binary_logloss: 0.171282	valid's auc: 0.733411	valid's binary_logloss: 0.172162
# [311]	train's auc: 0.738173	train's binary_logloss: 0.171276	valid's auc: 0.733423	valid's binary_logloss: 0.17216
# [312]	train's auc: 0.738213	train's binary_logloss: 0.171269	valid's auc: 0.733448	valid's binary_logloss: 0.172155
# [313]	train's auc: 0.738248	train's binary_logloss: 0.171263	valid's auc: 0.733459	valid's binary_logloss: 0.172153
# [314]	train's auc: 0.738278	train's binary_logloss: 0.171257	valid's auc: 0.733471	valid's binary_logloss: 0.17215
# [315]	train's auc: 0.738317	train's binary_logloss: 0.17125	valid's auc: 0.733484	valid's binary_logloss: 0.172147
# [316]	train's auc: 0.738376	train's binary_logloss: 0.171239	valid's auc: 0.73353	valid's binary_logloss: 0.172139
# [317]	train's auc: 0.738405	train's binary_logloss: 0.171233	valid's auc: 0.733553	valid's binary_logloss: 0.172133
# [318]	train's auc: 0.738446	train's binary_logloss: 0.171226	valid's auc: 0.733575	valid's binary_logloss: 0.172129
# [319]	train's auc: 0.738488	train's binary_logloss: 0.171219	valid's auc: 0.733605	valid's binary_logloss: 0.172124
# [320]	train's auc: 0.738527	train's binary_logloss: 0.171212	valid's auc: 0.733624	valid's binary_logloss: 0.17212
# [321]	train's auc: 0.738552	train's binary_logloss: 0.171205	valid's auc: 0.733641	valid's binary_logloss: 0.172115
# [322]	train's auc: 0.738591	train's binary_logloss: 0.171198	valid's auc: 0.733684	valid's binary_logloss: 0.172109
# [323]	train's auc: 0.73864	train's binary_logloss: 0.171191	valid's auc: 0.733719	valid's binary_logloss: 0.172104
# [324]	train's auc: 0.73868	train's binary_logloss: 0.171182	valid's auc: 0.733738	valid's binary_logloss: 0.172098
# [325]	train's auc: 0.738718	train's binary_logloss: 0.171176	valid's auc: 0.733758	valid's binary_logloss: 0.172095
# [326]	train's auc: 0.73876	train's binary_logloss: 0.171168	valid's auc: 0.733787	valid's binary_logloss: 0.17209
# [327]	train's auc: 0.738785	train's binary_logloss: 0.171162	valid's auc: 0.733786	valid's binary_logloss: 0.172087
# [328]	train's auc: 0.738839	train's binary_logloss: 0.171151	valid's auc: 0.733834	valid's binary_logloss: 0.172079
# [329]	train's auc: 0.738949	train's binary_logloss: 0.171135	valid's auc: 0.733935	valid's binary_logloss: 0.172064
# [330]	train's auc: 0.738987	train's binary_logloss: 0.171129	valid's auc: 0.733961	valid's binary_logloss: 0.17206
# [331]	train's auc: 0.739038	train's binary_logloss: 0.171119	valid's auc: 0.734002	valid's binary_logloss: 0.172053
# [332]	train's auc: 0.73908	train's binary_logloss: 0.171112	valid's auc: 0.734032	valid's binary_logloss: 0.172048
# [333]	train's auc: 0.739117	train's binary_logloss: 0.171105	valid's auc: 0.734056	valid's binary_logloss: 0.172043
# [334]	train's auc: 0.739175	train's binary_logloss: 0.171097	valid's auc: 0.734087	valid's binary_logloss: 0.172038
# [335]	train's auc: 0.739213	train's binary_logloss: 0.17109	valid's auc: 0.734106	valid's binary_logloss: 0.172034
# [336]	train's auc: 0.739245	train's binary_logloss: 0.171084	valid's auc: 0.734128	valid's binary_logloss: 0.17203
# [337]	train's auc: 0.739328	train's binary_logloss: 0.171069	valid's auc: 0.73421	valid's binary_logloss: 0.172017
# [338]	train's auc: 0.739365	train's binary_logloss: 0.171063	valid's auc: 0.734234	valid's binary_logloss: 0.172013
# [339]	train's auc: 0.739388	train's binary_logloss: 0.171058	valid's auc: 0.734241	valid's binary_logloss: 0.172011
# [340]	train's auc: 0.739461	train's binary_logloss: 0.171047	valid's auc: 0.734296	valid's binary_logloss: 0.172004
# [341]	train's auc: 0.739542	train's binary_logloss: 0.171035	valid's auc: 0.734356	valid's binary_logloss: 0.171994
# [342]	train's auc: 0.73957	train's binary_logloss: 0.17103	valid's auc: 0.734362	valid's binary_logloss: 0.171993
# [343]	train's auc: 0.739606	train's binary_logloss: 0.171024	valid's auc: 0.734374	valid's binary_logloss: 0.17199
# [344]	train's auc: 0.739631	train's binary_logloss: 0.171018	valid's auc: 0.734389	valid's binary_logloss: 0.171986
# [345]	train's auc: 0.739681	train's binary_logloss: 0.171009	valid's auc: 0.734413	valid's binary_logloss: 0.17198
# [346]	train's auc: 0.739732	train's binary_logloss: 0.171001	valid's auc: 0.734449	valid's binary_logloss: 0.171974
# [347]	train's auc: 0.739755	train's binary_logloss: 0.170995	valid's auc: 0.734469	valid's binary_logloss: 0.17197
# [348]	train's auc: 0.739792	train's binary_logloss: 0.170989	valid's auc: 0.734487	valid's binary_logloss: 0.171968
# [349]	train's auc: 0.739816	train's binary_logloss: 0.170984	valid's auc: 0.734498	valid's binary_logloss: 0.171965
# [350]	train's auc: 0.739868	train's binary_logloss: 0.170976	valid's auc: 0.734525	valid's binary_logloss: 0.17196
# [351]	train's auc: 0.73991	train's binary_logloss: 0.170971	valid's auc: 0.734535	valid's binary_logloss: 0.171959
# [352]	train's auc: 0.739932	train's binary_logloss: 0.170966	valid's auc: 0.734545	valid's binary_logloss: 0.171956
# [353]	train's auc: 0.739982	train's binary_logloss: 0.170956	valid's auc: 0.734583	valid's binary_logloss: 0.171949
# [354]	train's auc: 0.74002	train's binary_logloss: 0.170952	valid's auc: 0.734593	valid's binary_logloss: 0.171947
# [355]	train's auc: 0.740058	train's binary_logloss: 0.170946	valid's auc: 0.734606	valid's binary_logloss: 0.171944
# [356]	train's auc: 0.740087	train's binary_logloss: 0.170939	valid's auc: 0.734625	valid's binary_logloss: 0.17194
# [357]	train's auc: 0.740122	train's binary_logloss: 0.170929	valid's auc: 0.734647	valid's binary_logloss: 0.171932
# [358]	train's auc: 0.740149	train's binary_logloss: 0.170924	valid's auc: 0.734662	valid's binary_logloss: 0.17193
# [359]	train's auc: 0.740183	train's binary_logloss: 0.170919	valid's auc: 0.734667	valid's binary_logloss: 0.171928
# [360]	train's auc: 0.740207	train's binary_logloss: 0.170914	valid's auc: 0.73468	valid's binary_logloss: 0.171925
# [361]	train's auc: 0.740238	train's binary_logloss: 0.170909	valid's auc: 0.734682	valid's binary_logloss: 0.171924
# [362]	train's auc: 0.740287	train's binary_logloss: 0.170901	valid's auc: 0.734714	valid's binary_logloss: 0.171919
# [363]	train's auc: 0.74031	train's binary_logloss: 0.170897	valid's auc: 0.734728	valid's binary_logloss: 0.171917
# [364]	train's auc: 0.74033	train's binary_logloss: 0.170892	valid's auc: 0.734739	valid's binary_logloss: 0.171914
# [365]	train's auc: 0.740409	train's binary_logloss: 0.170881	valid's auc: 0.73481	valid's binary_logloss: 0.171905
# [366]	train's auc: 0.740454	train's binary_logloss: 0.170874	valid's auc: 0.734844	valid's binary_logloss: 0.1719
# [367]	train's auc: 0.740487	train's binary_logloss: 0.170868	valid's auc: 0.734858	valid's binary_logloss: 0.171896
# [368]	train's auc: 0.740517	train's binary_logloss: 0.170862	valid's auc: 0.734881	valid's binary_logloss: 0.171893
# [369]	train's auc: 0.740548	train's binary_logloss: 0.170856	valid's auc: 0.734898	valid's binary_logloss: 0.17189
# [370]	train's auc: 0.740567	train's binary_logloss: 0.170851	valid's auc: 0.734913	valid's binary_logloss: 0.171886
# [371]	train's auc: 0.740597	train's binary_logloss: 0.170845	valid's auc: 0.734928	valid's binary_logloss: 0.171883
# [372]	train's auc: 0.740639	train's binary_logloss: 0.170838	valid's auc: 0.734952	valid's binary_logloss: 0.171878
# [373]	train's auc: 0.740661	train's binary_logloss: 0.170833	valid's auc: 0.734953	valid's binary_logloss: 0.171876
# [374]	train's auc: 0.740689	train's binary_logloss: 0.170828	valid's auc: 0.734956	valid's binary_logloss: 0.171875
# [375]	train's auc: 0.74073	train's binary_logloss: 0.170821	valid's auc: 0.734976	valid's binary_logloss: 0.171871
# [376]	train's auc: 0.740751	train's binary_logloss: 0.170817	valid's auc: 0.734986	valid's binary_logloss: 0.171869
# [377]	train's auc: 0.740771	train's binary_logloss: 0.170812	valid's auc: 0.734992	valid's binary_logloss: 0.171868
# [378]	train's auc: 0.740882	train's binary_logloss: 0.170796	valid's auc: 0.735107	valid's binary_logloss: 0.171853
# [379]	train's auc: 0.74094	train's binary_logloss: 0.170787	valid's auc: 0.735135	valid's binary_logloss: 0.171846
# [380]	train's auc: 0.740985	train's binary_logloss: 0.17078	valid's auc: 0.735169	valid's binary_logloss: 0.171841
# [381]	train's auc: 0.741036	train's binary_logloss: 0.170772	valid's auc: 0.735203	valid's binary_logloss: 0.171835
# [382]	train's auc: 0.741068	train's binary_logloss: 0.170767	valid's auc: 0.735219	valid's binary_logloss: 0.171832
# [383]	train's auc: 0.741104	train's binary_logloss: 0.170761	valid's auc: 0.735234	valid's binary_logloss: 0.17183
# [384]	train's auc: 0.74114	train's binary_logloss: 0.170756	valid's auc: 0.735251	valid's binary_logloss: 0.171827
# [385]	train's auc: 0.741165	train's binary_logloss: 0.170751	valid's auc: 0.735266	valid's binary_logloss: 0.171825
# [386]	train's auc: 0.741194	train's binary_logloss: 0.170745	valid's auc: 0.735284	valid's binary_logloss: 0.171822
# [387]	train's auc: 0.741237	train's binary_logloss: 0.17074	valid's auc: 0.735307	valid's binary_logloss: 0.171819
# [388]	train's auc: 0.741261	train's binary_logloss: 0.170734	valid's auc: 0.735324	valid's binary_logloss: 0.171816
# [389]	train's auc: 0.741292	train's binary_logloss: 0.170728	valid's auc: 0.73535	valid's binary_logloss: 0.171812
# [390]	train's auc: 0.74134	train's binary_logloss: 0.17072	valid's auc: 0.735384	valid's binary_logloss: 0.171806
# [391]	train's auc: 0.741371	train's binary_logloss: 0.170713	valid's auc: 0.735399	valid's binary_logloss: 0.171802
# [392]	train's auc: 0.741422	train's binary_logloss: 0.170703	valid's auc: 0.735434	valid's binary_logloss: 0.171796
# [393]	train's auc: 0.741461	train's binary_logloss: 0.170697	valid's auc: 0.735451	valid's binary_logloss: 0.171793
# [394]	train's auc: 0.741493	train's binary_logloss: 0.170692	valid's auc: 0.735463	valid's binary_logloss: 0.171791
# [395]	train's auc: 0.741519	train's binary_logloss: 0.170687	valid's auc: 0.735472	valid's binary_logloss: 0.171789
# [396]	train's auc: 0.741554	train's binary_logloss: 0.170678	valid's auc: 0.735501	valid's binary_logloss: 0.171782
# [397]	train's auc: 0.741581	train's binary_logloss: 0.170672	valid's auc: 0.735518	valid's binary_logloss: 0.171778
# [398]	train's auc: 0.741612	train's binary_logloss: 0.170668	valid's auc: 0.735529	valid's binary_logloss: 0.171776
# [399]	train's auc: 0.741647	train's binary_logloss: 0.170661	valid's auc: 0.735556	valid's binary_logloss: 0.171772
# [400]	train's auc: 0.741668	train's binary_logloss: 0.170656	valid's auc: 0.735569	valid's binary_logloss: 0.171769
# [401]	train's auc: 0.741717	train's binary_logloss: 0.170648	valid's auc: 0.735606	valid's binary_logloss: 0.171763
# [402]	train's auc: 0.74174	train's binary_logloss: 0.170643	valid's auc: 0.735623	valid's binary_logloss: 0.171759
# [403]	train's auc: 0.741782	train's binary_logloss: 0.170636	valid's auc: 0.73564	valid's binary_logloss: 0.171755
# [404]	train's auc: 0.74183	train's binary_logloss: 0.17063	valid's auc: 0.735676	valid's binary_logloss: 0.171752
# [405]	train's auc: 0.741869	train's binary_logloss: 0.170623	valid's auc: 0.735699	valid's binary_logloss: 0.171747
# [406]	train's auc: 0.741895	train's binary_logloss: 0.17062	valid's auc: 0.735703	valid's binary_logloss: 0.171746
# [407]	train's auc: 0.741934	train's binary_logloss: 0.170613	valid's auc: 0.735727	valid's binary_logloss: 0.171742
# [408]	train's auc: 0.741961	train's binary_logloss: 0.170607	valid's auc: 0.735736	valid's binary_logloss: 0.171739
# [409]	train's auc: 0.742006	train's binary_logloss: 0.170601	valid's auc: 0.735764	valid's binary_logloss: 0.171735
# [410]	train's auc: 0.742044	train's binary_logloss: 0.170594	valid's auc: 0.735786	valid's binary_logloss: 0.171731
# ...
# [2011]	train's auc: 0.774279	train's binary_logloss: 0.164988	valid's auc: 0.743806	valid's binary_logloss: 0.170203
# [2012]	train's auc: 0.774292	train's binary_logloss: 0.164986	valid's auc: 0.743812	valid's binary_logloss: 0.170203
# [2013]	train's auc: 0.774301	train's binary_logloss: 0.164983	valid's auc: 0.743812	valid's binary_logloss: 0.170203
# [2014]	train's auc: 0.774316	train's binary_logloss: 0.16498	valid's auc: 0.74381	valid's binary_logloss: 0.170203
# [2015]	train's auc: 0.77433	train's binary_logloss: 0.164978	valid's auc: 0.743802	valid's binary_logloss: 0.170204
# [2016]	train's auc: 0.774348	train's binary_logloss: 0.164974	valid's auc: 0.743806	valid's binary_logloss: 0.170203
# [2017]	train's auc: 0.774362	train's binary_logloss: 0.164971	valid's auc: 0.743806	valid's binary_logloss: 0.170202
# [2018]	train's auc: 0.774371	train's binary_logloss: 0.164969	valid's auc: 0.743807	valid's binary_logloss: 0.170202
# [2019]	train's auc: 0.774381	train's binary_logloss: 0.164967	valid's auc: 0.743808	valid's binary_logloss: 0.170201
# [2020]	train's auc: 0.774397	train's binary_logloss: 0.164964	valid's auc: 0.74381	valid's binary_logloss: 0.170201
# [2021]	train's auc: 0.774404	train's binary_logloss: 0.164962	valid's auc: 0.743807	valid's binary_logloss: 0.170201
# [2022]	train's auc: 0.774417	train's binary_logloss: 0.16496	valid's auc: 0.74381	valid's binary_logloss: 0.170201
# [2023]	train's auc: 0.774434	train's binary_logloss: 0.164957	valid's auc: 0.743813	valid's binary_logloss: 0.170201
# [2024]	train's auc: 0.774443	train's binary_logloss: 0.164955	valid's auc: 0.743807	valid's binary_logloss: 0.170201
# [2025]	train's auc: 0.774457	train's binary_logloss: 0.164953	valid's auc: 0.743811	valid's binary_logloss: 0.170201
# [2026]	train's auc: 0.77447	train's binary_logloss: 0.16495	valid's auc: 0.743807	valid's binary_logloss: 0.170201
# [2027]	train's auc: 0.774476	train's binary_logloss: 0.164948	valid's auc: 0.743807	valid's binary_logloss: 0.1702
# [2028]	train's auc: 0.774492	train's binary_logloss: 0.164945	valid's auc: 0.743807	valid's binary_logloss: 0.170201
# [2029]	train's auc: 0.774502	train's binary_logloss: 0.164944	valid's auc: 0.743804	valid's binary_logloss: 0.170201
# [2030]	train's auc: 0.774508	train's binary_logloss: 0.164941	valid's auc: 0.743803	valid's binary_logloss: 0.170201
# [2031]	train's auc: 0.774525	train's binary_logloss: 0.164938	valid's auc: 0.743808	valid's binary_logloss: 0.170199
# [2032]	train's auc: 0.774542	train's binary_logloss: 0.164935	valid's auc: 0.743811	valid's binary_logloss: 0.170199
# [2033]	train's auc: 0.774557	train's binary_logloss: 0.164932	valid's auc: 0.743815	valid's binary_logloss: 0.170198
# [2034]	train's auc: 0.774567	train's binary_logloss: 0.16493	valid's auc: 0.743819	valid's binary_logloss: 0.170198
# [2035]	train's auc: 0.774579	train's binary_logloss: 0.164927	valid's auc: 0.74383	valid's binary_logloss: 0.170197
# [2036]	train's auc: 0.774589	train's binary_logloss: 0.164925	valid's auc: 0.743832	valid's binary_logloss: 0.170197
# [2037]	train's auc: 0.774606	train's binary_logloss: 0.164922	valid's auc: 0.74383	valid's binary_logloss: 0.170197
# [2038]	train's auc: 0.774619	train's binary_logloss: 0.164919	valid's auc: 0.743826	valid's binary_logloss: 0.170197
# [2039]	train's auc: 0.774637	train's binary_logloss: 0.164916	valid's auc: 0.743822	valid's binary_logloss: 0.170197
# [2040]	train's auc: 0.77465	train's binary_logloss: 0.164914	valid's auc: 0.743829	valid's binary_logloss: 0.170196
# [2041]	train's auc: 0.774665	train's binary_logloss: 0.164911	valid's auc: 0.743828	valid's binary_logloss: 0.170197
# [2042]	train's auc: 0.774684	train's binary_logloss: 0.164908	valid's auc: 0.74383	valid's binary_logloss: 0.170196
# [2043]	train's auc: 0.774703	train's binary_logloss: 0.164905	valid's auc: 0.743826	valid's binary_logloss: 0.170197
# [2044]	train's auc: 0.774717	train's binary_logloss: 0.164902	valid's auc: 0.743822	valid's binary_logloss: 0.170196
# [2045]	train's auc: 0.774737	train's binary_logloss: 0.1649	valid's auc: 0.743817	valid's binary_logloss: 0.170197
# [2046]	train's auc: 0.774756	train's binary_logloss: 0.164897	valid's auc: 0.743808	valid's binary_logloss: 0.170198
# [2047]	train's auc: 0.774773	train's binary_logloss: 0.164894	valid's auc: 0.743803	valid's binary_logloss: 0.170199
# [2048]	train's auc: 0.774781	train's binary_logloss: 0.164891	valid's auc: 0.743805	valid's binary_logloss: 0.170197
# [2049]	train's auc: 0.774792	train's binary_logloss: 0.164888	valid's auc: 0.743806	valid's binary_logloss: 0.170196
# [2050]	train's auc: 0.774804	train's binary_logloss: 0.164885	valid's auc: 0.743803	valid's binary_logloss: 0.170196
# [2051]	train's auc: 0.774813	train's binary_logloss: 0.164883	valid's auc: 0.743806	valid's binary_logloss: 0.170195
# [2052]	train's auc: 0.774826	train's binary_logloss: 0.164881	valid's auc: 0.743802	valid's binary_logloss: 0.170196
# [2053]	train's auc: 0.774836	train's binary_logloss: 0.164878	valid's auc: 0.743799	valid's binary_logloss: 0.170196
# [2054]	train's auc: 0.774852	train's binary_logloss: 0.164875	valid's auc: 0.743804	valid's binary_logloss: 0.170195
# [2055]	train's auc: 0.774877	train's binary_logloss: 0.164873	valid's auc: 0.743805	valid's binary_logloss: 0.170195
# [2056]	train's auc: 0.774898	train's binary_logloss: 0.16487	valid's auc: 0.743799	valid's binary_logloss: 0.170196
# [2057]	train's auc: 0.77491	train's binary_logloss: 0.164867	valid's auc: 0.743801	valid's binary_logloss: 0.170196
# [2058]	train's auc: 0.774924	train's binary_logloss: 0.164864	valid's auc: 0.743797	valid's binary_logloss: 0.170197
# [2059]	train's auc: 0.774933	train's binary_logloss: 0.164862	valid's auc: 0.7438	valid's binary_logloss: 0.170196
# [2060]	train's auc: 0.77495	train's binary_logloss: 0.164859	valid's auc: 0.743797	valid's binary_logloss: 0.170197
# [2061]	train's auc: 0.774967	train's binary_logloss: 0.164857	valid's auc: 0.743799	valid's binary_logloss: 0.170197
# [2062]	train's auc: 0.774984	train's binary_logloss: 0.164854	valid's auc: 0.743803	valid's binary_logloss: 0.170197
# [2063]	train's auc: 0.774995	train's binary_logloss: 0.164852	valid's auc: 0.743803	valid's binary_logloss: 0.170197
# [2064]	train's auc: 0.775002	train's binary_logloss: 0.164849	valid's auc: 0.743805	valid's binary_logloss: 0.170196
# [2065]	train's auc: 0.775021	train's binary_logloss: 0.164847	valid's auc: 0.743809	valid's binary_logloss: 0.170196
# [2066]	train's auc: 0.775044	train's binary_logloss: 0.164843	valid's auc: 0.743818	valid's binary_logloss: 0.170195
# [2067]	train's auc: 0.77506	train's binary_logloss: 0.16484	valid's auc: 0.743815	valid's binary_logloss: 0.170195
# [2068]	train's auc: 0.775078	train's binary_logloss: 0.164837	valid's auc: 0.743814	valid's binary_logloss: 0.170196
# [2069]	train's auc: 0.775098	train's binary_logloss: 0.164834	valid's auc: 0.743812	valid's binary_logloss: 0.170196
# [2070]	train's auc: 0.775112	train's binary_logloss: 0.164832	valid's auc: 0.743813	valid's binary_logloss: 0.170196
# [2071]	train's auc: 0.775127	train's binary_logloss: 0.164829	valid's auc: 0.743818	valid's binary_logloss: 0.170195
# [2072]	train's auc: 0.775146	train's binary_logloss: 0.164827	valid's auc: 0.743821	valid's binary_logloss: 0.170195
# [2073]	train's auc: 0.775168	train's binary_logloss: 0.164823	valid's auc: 0.74382	valid's binary_logloss: 0.170194
# [2074]	train's auc: 0.775175	train's binary_logloss: 0.164821	valid's auc: 0.743823	valid's binary_logloss: 0.170194
# [2075]	train's auc: 0.775181	train's binary_logloss: 0.164819	valid's auc: 0.743826	valid's binary_logloss: 0.170194
# [2076]	train's auc: 0.775187	train's binary_logloss: 0.164816	valid's auc: 0.743827	valid's binary_logloss: 0.170193
# [2077]	train's auc: 0.775201	train's binary_logloss: 0.164814	valid's auc: 0.74383	valid's binary_logloss: 0.170192
# [2078]	train's auc: 0.775217	train's binary_logloss: 0.164812	valid's auc: 0.743832	valid's binary_logloss: 0.170192
# [2079]	train's auc: 0.77523	train's binary_logloss: 0.164809	valid's auc: 0.743829	valid's binary_logloss: 0.170193
# [2080]	train's auc: 0.775238	train's binary_logloss: 0.164807	valid's auc: 0.743836	valid's binary_logloss: 0.170192
# [2081]	train's auc: 0.775247	train's binary_logloss: 0.164805	valid's auc: 0.743837	valid's binary_logloss: 0.170192
# [2082]	train's auc: 0.775261	train's binary_logloss: 0.164802	valid's auc: 0.743835	valid's binary_logloss: 0.170192
# [2083]	train's auc: 0.775273	train's binary_logloss: 0.164799	valid's auc: 0.743837	valid's binary_logloss: 0.170192
# [2084]	train's auc: 0.775289	train's binary_logloss: 0.164797	valid's auc: 0.743837	valid's binary_logloss: 0.170192
# [2085]	train's auc: 0.775301	train's binary_logloss: 0.164794	valid's auc: 0.743839	valid's binary_logloss: 0.170192
# [2086]	train's auc: 0.77531	train's binary_logloss: 0.164792	valid's auc: 0.743838	valid's binary_logloss: 0.170192
# [2087]	train's auc: 0.775324	train's binary_logloss: 0.16479	valid's auc: 0.743841	valid's binary_logloss: 0.170192
# [2088]	train's auc: 0.775334	train's binary_logloss: 0.164787	valid's auc: 0.743836	valid's binary_logloss: 0.170192
# [2089]	train's auc: 0.775353	train's binary_logloss: 0.164784	valid's auc: 0.743837	valid's binary_logloss: 0.170192
# [2090]	train's auc: 0.775369	train's binary_logloss: 0.164782	valid's auc: 0.743829	valid's binary_logloss: 0.170193
# [2091]	train's auc: 0.775384	train's binary_logloss: 0.16478	valid's auc: 0.743832	valid's binary_logloss: 0.170192
# [2092]	train's auc: 0.7754	train's binary_logloss: 0.164777	valid's auc: 0.743828	valid's binary_logloss: 0.170193
# [2093]	train's auc: 0.775413	train's binary_logloss: 0.164775	valid's auc: 0.743831	valid's binary_logloss: 0.170192
# [2094]	train's auc: 0.775423	train's binary_logloss: 0.164773	valid's auc: 0.743833	valid's binary_logloss: 0.170192
# [2095]	train's auc: 0.775433	train's binary_logloss: 0.164771	valid's auc: 0.743836	valid's binary_logloss: 0.170191
# [2096]	train's auc: 0.775445	train's binary_logloss: 0.164768	valid's auc: 0.743844	valid's binary_logloss: 0.17019
# [2097]	train's auc: 0.77545	train's binary_logloss: 0.164766	valid's auc: 0.743841	valid's binary_logloss: 0.17019
# [2098]	train's auc: 0.775465	train's binary_logloss: 0.164764	valid's auc: 0.743837	valid's binary_logloss: 0.170191
# [2099]	train's auc: 0.775476	train's binary_logloss: 0.164762	valid's auc: 0.743834	valid's binary_logloss: 0.170191
# [2100]	train's auc: 0.775491	train's binary_logloss: 0.164759	valid's auc: 0.743834	valid's binary_logloss: 0.170191
# [2101]	train's auc: 0.775509	train's binary_logloss: 0.164756	valid's auc: 0.743837	valid's binary_logloss: 0.17019
# [2102]	train's auc: 0.775529	train's binary_logloss: 0.164753	valid's auc: 0.743836	valid's binary_logloss: 0.170191
# [2103]	train's auc: 0.77554	train's binary_logloss: 0.16475	valid's auc: 0.743844	valid's binary_logloss: 0.170189
# [2104]	train's auc: 0.77556	train's binary_logloss: 0.164747	valid's auc: 0.743844	valid's binary_logloss: 0.170189
# [2105]	train's auc: 0.775579	train's binary_logloss: 0.164744	valid's auc: 0.743834	valid's binary_logloss: 0.17019
# [2106]	train's auc: 0.775589	train's binary_logloss: 0.164742	valid's auc: 0.743837	valid's binary_logloss: 0.170191
# [2107]	train's auc: 0.775601	train's binary_logloss: 0.16474	valid's auc: 0.743841	valid's binary_logloss: 0.17019
# [2108]	train's auc: 0.775616	train's binary_logloss: 0.164737	valid's auc: 0.743839	valid's binary_logloss: 0.17019
# [2109]	train's auc: 0.775636	train's binary_logloss: 0.164734	valid's auc: 0.743844	valid's binary_logloss: 0.170189
# [2110]	train's auc: 0.77566	train's binary_logloss: 0.164731	valid's auc: 0.743838	valid's binary_logloss: 0.17019
# [2111]	train's auc: 0.775676	train's binary_logloss: 0.164728	valid's auc: 0.743835	valid's binary_logloss: 0.17019
# [2112]	train's auc: 0.775683	train's binary_logloss: 0.164726	valid's auc: 0.743834	valid's binary_logloss: 0.17019
# [2113]	train's auc: 0.775692	train's binary_logloss: 0.164723	valid's auc: 0.743829	valid's binary_logloss: 0.17019
# [2114]	train's auc: 0.775707	train's binary_logloss: 0.16472	valid's auc: 0.743825	valid's binary_logloss: 0.170191
# [2115]	train's auc: 0.775729	train's binary_logloss: 0.164718	valid's auc: 0.74383	valid's binary_logloss: 0.17019
# [2116]	train's auc: 0.775749	train's binary_logloss: 0.164715	valid's auc: 0.743831	valid's binary_logloss: 0.17019
# [2117]	train's auc: 0.775763	train's binary_logloss: 0.164713	valid's auc: 0.743828	valid's binary_logloss: 0.170191
# [2118]	train's auc: 0.775779	train's binary_logloss: 0.16471	valid's auc: 0.74382	valid's binary_logloss: 0.170191
# [2119]	train's auc: 0.775794	train's binary_logloss: 0.164708	valid's auc: 0.743811	valid's binary_logloss: 0.170192
# [2120]	train's auc: 0.775805	train's binary_logloss: 0.164705	valid's auc: 0.743805	valid's binary_logloss: 0.170192
# [2121]	train's auc: 0.775826	train's binary_logloss: 0.164702	valid's auc: 0.74381	valid's binary_logloss: 0.170192
# [2122]	train's auc: 0.775843	train's binary_logloss: 0.164699	valid's auc: 0.743811	valid's binary_logloss: 0.170191
# [2123]	train's auc: 0.775859	train's binary_logloss: 0.164696	valid's auc: 0.743807	valid's binary_logloss: 0.170191
# [2124]	train's auc: 0.775867	train's binary_logloss: 0.164694	valid's auc: 0.743808	valid's binary_logloss: 0.17019
# [2125]	train's auc: 0.775886	train's binary_logloss: 0.164691	valid's auc: 0.743805	valid's binary_logloss: 0.170191
# [2126]	train's auc: 0.775904	train's binary_logloss: 0.164689	valid's auc: 0.743802	valid's binary_logloss: 0.170191
# [2127]	train's auc: 0.775918	train's binary_logloss: 0.164687	valid's auc: 0.743804	valid's binary_logloss: 0.170191
# [2128]	train's auc: 0.775937	train's binary_logloss: 0.164684	valid's auc: 0.743805	valid's binary_logloss: 0.170191
# [2129]	train's auc: 0.77595	train's binary_logloss: 0.164681	valid's auc: 0.743805	valid's binary_logloss: 0.17019
# [2130]	train's auc: 0.775965	train's binary_logloss: 0.164678	valid's auc: 0.743807	valid's binary_logloss: 0.17019
# [2131]	train's auc: 0.775984	train's binary_logloss: 0.164675	valid's auc: 0.743808	valid's binary_logloss: 0.17019
# [2132]	train's auc: 0.776001	train's binary_logloss: 0.164673	valid's auc: 0.743807	valid's binary_logloss: 0.17019
# [2133]	train's auc: 0.77602	train's binary_logloss: 0.16467	valid's auc: 0.743807	valid's binary_logloss: 0.170189
# [2134]	train's auc: 0.776035	train's binary_logloss: 0.164667	valid's auc: 0.743801	valid's binary_logloss: 0.17019
# [2135]	train's auc: 0.77605	train's binary_logloss: 0.164665	valid's auc: 0.743804	valid's binary_logloss: 0.17019
# [2136]	train's auc: 0.776073	train's binary_logloss: 0.164661	valid's auc: 0.74381	valid's binary_logloss: 0.170189
# [2137]	train's auc: 0.77609	train's binary_logloss: 0.164658	valid's auc: 0.743809	valid's binary_logloss: 0.170188
# [2138]	train's auc: 0.776104	train's binary_logloss: 0.164655	valid's auc: 0.743812	valid's binary_logloss: 0.170188
# [2139]	train's auc: 0.776118	train's binary_logloss: 0.164653	valid's auc: 0.743812	valid's binary_logloss: 0.170188
# [2140]	train's auc: 0.776129	train's binary_logloss: 0.164651	valid's auc: 0.743814	valid's binary_logloss: 0.170187
# [2141]	train's auc: 0.776139	train's binary_logloss: 0.164648	valid's auc: 0.743812	valid's binary_logloss: 0.170187
# [2142]	train's auc: 0.776157	train's binary_logloss: 0.164645	valid's auc: 0.743823	valid's binary_logloss: 0.170186
# [2143]	train's auc: 0.776175	train's binary_logloss: 0.164642	valid's auc: 0.743829	valid's binary_logloss: 0.170185
# [2144]	train's auc: 0.776188	train's binary_logloss: 0.16464	valid's auc: 0.74382	valid's binary_logloss: 0.170186
# [2145]	train's auc: 0.776211	train's binary_logloss: 0.164637	valid's auc: 0.743824	valid's binary_logloss: 0.170185
# [2146]	train's auc: 0.776222	train's binary_logloss: 0.164635	valid's auc: 0.743823	valid's binary_logloss: 0.170185
# Early stopping, best iteration is:
# [2096]	train's auc: 0.775445	train's binary_logloss: 0.164768	valid's auc: 0.743844	valid's binary_logloss: 0.17019

# %%
from sklearn.metrics import roc_auc_score, log_loss
print('===================Test Set Performance===================')
y_valid_pred = clf.predict_proba(x_valid2save, num_iteration = clf.best_iteration_)[:,1]
print(pd.Series(y_valid_pred).describe())

# round(pd.Series(evals_ypre),6).to_csv('data_preprocessing/evals_ypre_'+str(i+1)+'.csv',index=False)
print('Test AUC', roc_auc_score(y_valid, y_valid_pred))
print('Test Logloss', log_loss(y_valid, y_valid_pred))
# Out:
# ===================Test Set Performance===================
# count    1.759974e+06
# mean     4.796217e-02
# std      5.839436e-02
# min      2.186377e-04
# 25%      2.071137e-02
# 50%      3.481173e-02
# 75%      5.510371e-02
# max      9.953930e-01
# dtype: float64
# Test AUC 0.7438440879170812
# Test Logloss 0.17018985844814913

# %% [markdown]
# # 组合ID特征

# %%
label_feat_lst = ['aid', 'advertiserId', 'campaignId', 'creativeId',
                  'creativeSize', 'adCategoryId', 'productId', 'productType', 'age',
                  'gender','education', 'consumptionAbility', 'LBS',
                  'os', 'carrier', 'house']

# %%
df_data = df_data[label_feat_lst]

for feature in tqdm(label_feat_lst):
    try:
        df_data[feature] = LabelEncoder().fit_transform(df_data[feature].apply(int))
    except:
        df_data[feature] = LabelEncoder().fit_transform(df_data[feature])
# Out:
# 100%|██████████| 16/16 [00:56<00:00,  3.51s/it]

# %%
train_part_x_sparse = pd.DataFrame()
evals_x_sparse = pd.DataFrame()

feat_len = len(label_feat_lst)
enc = OneHotEncoder()
num = 0
for i in range(feat_len):
    for j in range(feat_len - i - 1):
        s = time.time()
        # 握手问题, 每一个feat都要和其他feat计算一次
        print(label_feat_lst[i], label_feat_lst[i + j + 1])
#         se = df_data[label_feat_lst[i]] * 100000 + df_data[label_feat_lst[i + j + 1]] * 1
#         enc.fit(se.values.reshape(-1, 1))
        
#         se = data.loc[train_part_index][col[i]]*100000+data.loc[train_part_index][col[i+j+1]]*1
#         arr =enc.transform(se.values.reshape(-1, 1))
#         train_part_x_sparse = sparse.hstack((train_part_x_sparse, arr))

        
#         se = data.loc[evals_index][col[i]]*100000+data.loc[evals_index][col[i+j+1]]*1
#         arr = enc.transform(se.values.reshape(-1, 1))
#         evals_x_sparse = sparse.hstack((evals_x_sparse,arr))

#         num+=1
#         arr = []
#         print(num,col[i],col[i+j+1],int(time.time()-s),"s")
#         if num % 12==0:
#             k = num//12
#             ##存写组合稀疏矩阵
#             print("Saving...")
#             print(k)
#             print('train_part_x...')
#             sparse.save_npz('data_preprocessing/train_part_x_sparse_two_'+str(k)+'.npz',train_part_x_sparse)
#             print('evals_x...')
#             sparse.save_npz('data_preprocessing/evals_x_sparse_two_'+str(k)+'.npz',evals_x_sparse)
#             print('test1_x...')
#             sparse.save_npz('data_preprocessing/test1_x_sparse_two_'+str(k)+'.npz',test1_x_sparse)
#             print('test2_x...')
#             sparse.save_npz('data_preprocessing/test2_x_sparse_two_'+str(k)+'.npz',test2_x_sparse)
#             print('Over')
#             train_part_x_sparse=pd.DataFrame()
#             evals_x_sparse=pd.DataFrame()
#             test1_x_sparse=pd.DataFrame()
#             test2_x_sparse=pd.DataFrame()
# Out:
# aid advertiserId
# aid campaignId
# aid creativeId
# aid creativeSize
# aid adCategoryId
# aid productId
# aid productType
# aid age
# aid gender
# aid education
# aid consumptionAbility
# aid LBS
# aid os
# aid carrier
# aid house
# advertiserId campaignId
# advertiserId creativeId
# advertiserId creativeSize
# advertiserId adCategoryId
# advertiserId productId
# advertiserId productType
# advertiserId age
# advertiserId gender
# advertiserId education
# advertiserId consumptionAbility
# advertiserId LBS
# advertiserId os
# advertiserId carrier
# advertiserId house
# campaignId creativeId
# campaignId creativeSize
# campaignId adCategoryId
# campaignId productId
# campaignId productType
# campaignId age
# campaignId gender
# campaignId education
# campaignId consumptionAbility
# campaignId LBS
# campaignId os
# campaignId carrier
# campaignId house
# creativeId creativeSize
# creativeId adCategoryId
# creativeId productId
# creativeId productType
# creativeId age
# creativeId gender
# creativeId education
# creativeId consumptionAbility
# creativeId LBS
# creativeId os
# creativeId carrier
# creativeId house
# creativeSize adCategoryId
# creativeSize productId
# creativeSize productType
# creativeSize age
# creativeSize gender
# creativeSize education
# creativeSize consumptionAbility
# creativeSize LBS
# creativeSize os
# creativeSize carrier
# creativeSize house
# adCategoryId productId
# adCategoryId productType
# adCategoryId age
# adCategoryId gender
# adCategoryId education
# adCategoryId consumptionAbility
# adCategoryId LBS
# adCategoryId os
# adCategoryId carrier
# adCategoryId house
# productId productType
# productId age
# productId gender
# productId education
# productId consumptionAbility
# productId LBS
# productId os
# productId carrier
# productId house
# productType age
# productType gender
# productType education
# productType consumptionAbility
# productType LBS
# productType os
# productType carrier
# productType house
# age gender
# age education
# age consumptionAbility
# age LBS
# age os
# age carrier
# age house
# gender education
# gender consumptionAbility
# gender LBS
# gender os
# gender carrier
# gender house
# education consumptionAbility
# education LBS
# education os
# education carrier
# education house
# consumptionAbility LBS
# consumptionAbility os
# consumptionAbility carrier
# consumptionAbility house
# LBS os
# LBS carrier
# LBS house
# os carrier
# os house
# carrier house

# %% [markdown]
# # 模型构建

# %%
def model_evaluation(y_train, y_train_pred, y_test, y_test_pred, model_name=''):
    """

    :param y_train:
    :type y_train:
    :param y_train_pred:
    :type y_train_pred:
    :param y_test:
    :type y_test:
    :param y_test_pred:
    :type y_test_pred:
    :param model_name:
    :type model_name:
    :return:
    :rtype:
    """
    print("{} Train AUC: {}, logloss: {}".format(model_name, roc_auc_score(y_train, y_train_pred), log_loss(y_train, y_train_pred)))
    # print("{} Train confusion matrix: {}".format(model_name, confusion_matrix(y_train, y_train_pred)))

    print("{} Test AUC: {}, logloss: {}".format(model_name, roc_auc_score(y_test, y_test_pred), log_loss(y_test, y_test_pred)))
    # print("{} Test confusion matrix: {}".format(model_name, confusion_matrix(y_test, y_test_pred)))

# %% [markdown]
# ## Baseline版本
# - 只使用离散特征，进行onehot编码
# - 线性模型：LogisticRegression

# %%
print(x_train.shape, x_valid.shape)
# baseline版本
turned_param = {
        'penalty': 'l2',
        'C': 10,
        'solver': 'lbfgs',
        'tol': 1e-4,
        'max_iter': 10000
    }

clf = LogisticRegression(random_state=1, **turned_param)
clf.fit(x_train, y_train)

y_train_pred = clf.predict(x_train)
y_test_pred = clf.predict(x_valid)

model_evaluation(y_train, y_train_pred, y_valid, y_test_pred, model_name='LogisticRegression')
# Out:
# (7038840, 1526) (1759974, 1526)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c7a591b41f22> in <module>
#      15 y_test_pred = clf.predict(x_valid)
#      16
# ---> 17 model_evaluation(y_train, y_train_pred, y_valid, y_test_pred, model_name='LogisticRegression')
#
# NameError: name 'model_evaluation' is not defined

# %%
# 基于相似度
# Out:
# LogisticRegression Train AUC: 0.5000014816351326, logloss: 1.6558969428673103
# LogisticRegression Test AUC: 0.5, logloss: 1.6581997519647336

# %%
for i, j in enumerate([1,1,1]):
    print(i, j)
# Out:
# 0 1
# 1 1
# 2 1
